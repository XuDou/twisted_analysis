# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from urllib.request import urlopen

# %%
arxiv_urls = ['https://arxiv.org/archive/cond-mat']

key_words_set1 = ["magic angle"]

def build_dataset(arxiv_urls):
    news_data = []
    for url in arxiv_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        
        news_articles = [{'news_headline': headline.find('span', 
                                                         attrs={"itemprop": "headline"}).string,
                          'news_article': article.find('div', 
                                                       attrs={"itemprop": "articleBody"}).string,
                          'news_category': news_category}
                         
                            for headline, article in 
                             zip(soup.find_all('div', 
                                               class_=["news-card-title news-right-box"]),
                                 soup.find_all('div', 
                                               class_=["news-card-content news-right-box"]))
                        ]
        news_data.extend(news_articles)
        
    df =  pd.DataFrame(news_data)
    df = df[['news_headline', 'news_article', 'news_category']]
    return df

# %%
r = requests.get(google_scholar_url + query)

# %%
r.encoding
# Out:
# 'ISO-8859-1'

# %%
google_scholar_url = "http://scholar.google.se/scholar?hl=en&q="

# %%
print(google_scholar_url + query)
# Out:
# http://scholar.google.se/scholar?hl=en&q=gravity

# %%
query = "gravity"

# %%
html = urlopen(google_scholar_url + query).read()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-16-85e8f8250fe3> in <module>()
# ----> 1 html = urlopen(google_scholar_url + query).read()
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda/envs/py36/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
text = åß
print(text.)

# %%
text = BeautifulSoup(r.text,'html.parser')

# %%
print(text.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <title>
#    Google Scholar
#   </title>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="always" name="referrer"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <style>
#    html,body,form,table,div,h1,h2,h3,h4,h5,h6,img,ol,ul,li,button{margin:0;padding:0;border:0;}table{border-collapse:collapse;border-width:0;empty-cells:show;}html,body{height:100%}#gs_top{position:relative;box-sizing:border-box;min-height:100%;min-width:964px;-webkit-tap-highlight-color:rgba(0,0,0,0);}#gs_top>*:not(#x){-webkit-tap-highlight-color:rgba(204,204,204,.5);}.gs_el_ph #gs_top,.gs_el_ta #gs_top{min-width:320px;}#gs_top.gs_nscl{position:fixed;width:100%;}body,td,input,button{font-size:13px;font-family:Arial,sans-serif;line-height:1.24;}body{background:#fff;color:#222;-webkit-text-size-adjust:100%;-moz-text-size-adjust:none;}.gs_gray{color:#777777}.gs_red{color:#dd4b39}.gs_grn{color:#006621}.gs_lil{font-size:11px}.gs_med{font-size:16px}.gs_hlt{font-weight:bold;}a:link{color:#1a0dab;text-decoration:none}a:visited{color:#660099;text-decoration:none}a:hover,a:hover .gs_lbl{text-decoration:underline}a:active,a:active .gs_lbl,a .gs_lbl:active{color:#d14836}.gs_el_tc a:hover,.gs_el_tc a:hover .gs_lbl{text-decoration:none}.gs_pfcs a:focus,.gs_pfcs button:focus,.gs_pfcs input:focus,.gs_pfcs label:focus{outline:none}.gs_a,.gs_a a:link,.gs_a a:visited{color:#006621}.gs_a a:active{color:#d14836}a.gs_fl:link,.gs_fl a:link{color:#1a0dab}a.gs_fl:visited,.gs_fl a:visited{color:#660099}a.gs_fl:active,.gs_fl a:active{color:#d14836}.gs_fl{color:#777777}.gs_ctc,.gs_ctu{vertical-align:middle;font-size:11px;font-weight:bold}.gs_ctc{color:#1a0dab}.gs_ctg,.gs_ctg2{font-size:13px;font-weight:bold}.gs_ctg{color:#1a0dab}a.gs_pda,.gs_pda a{padding:7px 0 5px 0}.gs_alrt{background:#f9edbe;border:1px solid #f0c36d;padding:0 16px;text-align:center;box-shadow:0 2px 4px rgba(0,0,0,.2);border-radius:2px;}.gs_spc{display:inline-block;width:12px}.gs_br{width:0;font-size:0}.gs_ibl{display:inline-block;}.gs_scl:after{content:"";display:table;clear:both;}.gs_ind{padding-left:8px;text-indent:-8px}.gs_ico,.gs_icm{display:inline-block;background:no-repeat url(/intl/en/scholar/images/1x/sprite_20161020.png);background-position:-23px -161px;background-size:169px;width:21px;height:21px;}@media(-webkit-min-device-pixel-ratio:1.5),(min-resolution:144dpi){.gs_ico,.gs_icm{background-image:url(/intl/en/scholar/images/2x/sprite_20161020.png);}}.gs_el_ta .gs_nta,.gs_ota,.gs_el_ph .gs_nph,.gs_oph{display:none}.gs_el_ta .gs_ota,.gs_el_ph .gs_oph{display:inline}.gs_el_ta div.gs_ota,.gs_el_ph div.gs_oph{display:block}.gs_sth_g{visibility:hidden;max-height:0;}.gs_sth_vis .gs_sth_g{max-height:1000px;}.gs_sth_vis .gs_sth_b{position:fixed;top:0;}@keyframes gs_anm_spin{0%{transform:rotate(0deg);}100%{transform:rotate(360deg);}}.gs_rimg{display:block;background-color:#e5e5e5;border-radius:50%;overflow:hidden;position:relative;z-index:1;}.gs_rimg>img{position:absolute;margin:auto;left:0;top:0;bottom:0;right:0;}.gs_in_txtw{display:inline-block;vertical-align:middle;}.gs_in_txtb{display:block;}.gs_in_txt{color:#000;background-color:#fff;font-size:16px;box-sizing:border-box;height:29px;line-height:23px;border:1px solid #d9d9d9;border-top-color:#c0c0c0;padding:3px 6px 1px 8px;border-radius:1px;outline:none;-webkit-appearance:none;-moz-appearance:none;}.gs_el_tc .gs_in_txt{font-size:18px;}.gs_in_txtb .gs_in_txt{width:100%;}.gs_in_txt:hover{border-color:#b9b9b9;border-top-color:#a0a0a0;box-shadow:inset 0 1px 2px rgba(0,0,0,.1);}.gs_in_txte .gs_in_txt{border-color:#dd4b39;}.gs_in_txt:focus{border-color:#4d90fe;box-shadow:inset 0 1px 2px rgba(0,0,0,.3);}.gs_in_txt:disabled{color:#b8b8b8;border-color:#f1f1f1;box-shadow:none;}.gs_in_txtm .gs_in_txt{font-size:13px;height:24px;line-height:16px;padding:3px 6px;}.gs_el_tc .gs_in_txtm .gs_in_txt{height:29px;line-height:21px;}.gs_in_txts{font-size:13px;line-height:18px;color:#666;}.gs_in_txte .gs_in_txts{color:#dd4b39;}button{position:relative;z-index:1;box-sizing:border-box;font-size:13px;cursor:pointer;height:29px;line-height:normal;min-width:72px;padding:0 8px;color:#444;border:1px solid rgba(0,0,0,.1);border-radius:3px;text-align:center;backg ...
#   </style>
#   <script>
#    !function(GSP){var k,aa=function(a){return"string"==typeof a},ba=function(){},ca=function(a){var b=typeof a;if("object"==b)if(a){if(a instanceof Array)return"array";if(a instanceof Object)return b;var c=Object.prototype.toString.call(a);if("[object Window]"==c)return"object";if("[object Array]"==c||"number"==typeof a.length&&"undefined"!=typeof a.splice&&"undefined"!=typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("splice"))return"array";if("[object Function]"==c||"undefined"!=typeof a.call&&"undefined"!=
# typeof a.propertyIsEnumerable&&!a.propertyIsEnumerable("call"))return"function"}else return"null";else if("function"==b&&"undefined"==typeof a.call)return"object";return b},da=function(a){var b=typeof a;return"object"==b&&null!=a||"function"==b},n=function(a){return a[fa]||(a[fa]=++ha)},fa="closure_uid_"+(1E9*Math.random()>>>0),ha=0,ia=function(a,b){var c=Array.prototype.slice.call(arguments,1);return function(){var b=c.slice();b.push.apply(b,arguments);return a.apply(this,b)}},ja=function(a,b){function c(){}
# c.prototype=b.prototype;a.ob=b.prototype;a.prototype=new c;a.prototype.constructor=a;a.pb=function(a,c,f){for(var d=Array(arguments.length-2),e=2;e<arguments.length;e++)d[e-2]=arguments[e];return b.prototype[c].apply(a,d)}};var ka=function(){this.R=this.R;this.W=this.W};ka.prototype.R=!1;ka.prototype.ua=function(){this.R||(this.R=!0,this.$())};ka.prototype.$=function(){if(this.W)for(;this.W.length;)this.W.shift()()};var p=function(a,b){a.classList.add(b)},q=function(a,b){a.classList.remove(b)},t=function(a,b){return a.classList?a.classList.contains(b):!1},u=function(a,b,c){c=void 0!==c?c:!t(a,b);(c?p:q)(a,b)};var la,v=function(a){return 0<=(navigator.userAgent||"").indexOf(a)},ma=v("iPhone")||v("iPad")||v("iPod"),na=v("iPhone")||v("Android")&&v("Mobile"),oa=function(){var a=window.screen,b=window.innerWidth,c=window.innerHeight,d=a.width;a=a.height;var e=4;if(600>b||48E4>d*a||na)e=1;else if(982>b)e=2;else if(1136>b||590>c)e=3;return e},pa,qa=/[?&]tc=([01])/.exec(location.search||"");
# pa=qa?0<+qa[1]:v("Android")?!0:window.matchMedia&&window.matchMedia("(pointer)").matches?window.matchMedia("(pointer:coarse)").matches:!v("Firefox")||v("Mobile")||v("Tablet")?ma||"ontouchstart"in window||0<(navigator.msMaxTouchPoints||0):!1;var ra=function(){if(void 0==la){la=!1;try{var a=Object.defineProperty({},"passive",{get:function(){la=!0}});window.addEventListener("testPassive",ba,a);window.removeEventListener("testPassive",ba,a)}catch(b){}}return la};var w=function(a){return document.getElementById(a)},z=function(a){return a.id||(a.id="gs_id"+sa++)},ta=function(a){return a?getComputedStyle(a,null):null},ua=function(a,b){var c=[];a=a.elements;for(var d=a.length,e=0;e<d;e++){var f=a[e],g=encodeURIComponent(f.name||""),h=f.type;!g||b&&!b(f)||f.disabled||!("checkbox"!=h&&"radio"!=h||f.checked)||c.push(g+"="+encodeURIComponent(f.value||""))}return c.join("&")},va=function(a){var b=a.elements.scipsc;b||(b=document.createElement("input"),b.type="hidden",
# b.name="scipsc",a.appendChild(b));return b},xa=function(a){a.match(wa)&&(window.location.href=a)},sa=100,ya=/\S+/g,wa=/^(?:https?:|[^:/?#]*(?:[/?#]|$))/i,za=/^(?:#|\/[a-z0-9_-]*(?:[?].*)?$)/i;var A=function(){this.f=[];this.O={};this.ja=this.A=0};A.prototype.add=function(a){var b=n(a);this.O[b]||(this.f.push(a),this.O[b]=this.f.length,++this.A)};A.prototype.remove=function(a){a=n(a);var b=this.O[a];b&&(this.f[b-1]=null,delete this.O[a],2*--this.A<this.f.length&&!this.ja&&Aa(this))};A.prototype.v=function(a){var b=this.f;try{++this.ja;for(var c=0;c<b.length;c++){var d=b[c];d&&d.apply(null,arguments)}}finally{!--this.ja&&2*this.A<b.length&&Aa(this)}};
# var Aa=function(a){var b=a.f,c=b.length;a=a.O;for(var d=0,e=0;e<c;e++){var f=b[e];f&&(b[d]=f,a[n(f)]=++d)}b.length=d};var Ba,B=function(a,b,c,d,e){Ca(a,b,c,!!d,!!e,Da)},C=function(a,b,c,d){Ca(a,b,c,!!d,!1,Ea)},Fa=function(a,b,c,d,e){function f(e){C(a,b,f,d);c(e)}B(a,b,f,d,e);return f},Ga=function(a,b,c,d,e){var f=Fa(a,b,function(a){clearTimeout(g);c(a)}),g=setTimeout(function(){C(a,b,f);e&&e()},d)},E=function(a){Ba?Ba.add(a):a()},Ha=window.requestAnimationFrame?function(a){window.requestAnimationFrame(a)}:function(a){setTimeout(a,33)},Ia=function(a){a.stopPropagation();a.preventDefault()},Ja=function(a){return(a.ctrlKey?
# 1:0)|(a.altKey?2:0)|(a.metaKey?4:0)|(a.shiftKey?8:0)},Ka=function(a,b){return(b=b&&ra())?{passive:b,capture:a}:a},Da=function(a,b,c,d,e){a.addEventListener(b,c,Ka(d,e))},Ea=function(a,b,c,d){a.removeEventListener(b,c,d)},Ca=function(a,b,c,d,e,f){if(aa(b))f(a,b,c,d,e);else for(var g=b.length,h=0;h<g;h++)f(a,b[h],c,d,e)},La=function(){Ba.v();Ba=null},Na=function(){"complete"==document.readyState&&(C(document,"readystatechange",Na),La())},Oa=!!document.attachEvent,Pa=document.readyState;
# if(Oa?"complete"!=Pa:"loading"==Pa)Ba=new A,Oa?B(document,"readystatechange",Na):Fa(document,"DOMContentLoaded",La);var Ra=function(){Fa(document,["mousedown","touchstart"],function(){u(document.documentElement,"gs_pfcs",!0);B(document,"keydown",Qa,!0)},!0,!0)},Qa=function(a){9==a.keyCode&&(u(document.documentElement,"gs_pfcs",!1),C(document,"keydown",Qa,!0),Ra())};Ra();var Ta=function(a,b,c,d,e){var f=w(a);Sa(f,function(){p(f,"gs_vis");b&&b()},function(){q(f,"gs_vis");c&&c()},d,e)},Sa=function(a,b,c,d,e){var f=z(a);if(!F[f]){var g=document.activeElement;Ua(Va(a),!0);b&&b();H.push(function(a){delete F[f];try{a||(e||g).focus()}catch(l){}c&&c()});F[f]=H.length;g&&a.contains(g)||setTimeout(function(){var b=d,c=b&&"text"==b.type;if(!b||c&&pa)b=a;try{b.focus(),c&&(b.value=b.value)}catch(y){}},0)}},I=function(a){Ua((F[a]||1E6)-1,void 0)},Ua=function(a,b){for(;H.length>
# a;){var c=b||H.length>a+1;H.pop()(!!c)}},Va=function(a){for(var b=0;a&&!(b=F[a.id]||0);)a=a.parentNode;return b},H=[],F={};B(document,"click",function(a){var b=H.length;b&&!Ja(a)&&b>Va(a.target)&&H.pop()(!0)});B(document,"keydown",function(a){27==a.keyCode&&!Ja(a)&&H.length&&H.pop()(!1)});
# B(document,"focus",function(a){var b=H.length;if(b)for(var c=Va(a.target);c<b;){var d="",e;for(e in F)if(F[e]==b){d=e;break}a:{d=(w(d).getAttribute("data-wfc")||"").match(ya)||[];for(var f=0;f<d.length;f++){var g=w(d[f]);if(g&&g.offsetWidth){d=g;break a}}d=void 0}if(d){Ia(a);d.focus();break}else H.pop()(!0),--b}},!0);var Wa,Ya=function(a){w("gs_alrt_m").innerHTML=a;w("gs_alrt").action=("".match(wa),"");w("gs_alrt_l").textContent="";w("gs_alrt_h").innerHTML="";Xa()},Za=function(){var a=w("gs_alrt_ss");return!!a&&!!a.value},Xa=function(){var a=w("gs_alrt_w");p(a,"gs_anm");p(a,"gs_vis");B(document,"click",J);B(window,"scroll",J);clearTimeout(Wa);Wa=setTimeout(J,6E4);++$a;setTimeout(ab,0)},J=function(){$a||(C(document,"click",J),C(window,"scroll",J),clearTimeout(Wa),Wa=void 0,q(w("gs_alrt_w"),"gs_vis"))},ab=function(){$a=
# 0},$a=0;E(function(){var a=w("gs_alrt_ss");a&&(w("gs_alrt_m").innerHTML&&!a.value&&Xa(),B(window,"pagehide",function(){$a=0;J();q(w("gs_alrt_w"),"gs_anm")}),setTimeout(function(){a.value="1"},0))});var K=function(a,b,c){b=b||bb;b.length=0;a.normalize&&(a=a.normalize("NFKD").replace(cb,""));return a.toLowerCase().replace(db,function(d,e){b.length||e&&b.push(0);b.push(d.length);return e&&(!c||e+d.length<a.length)?" ":""})},fb=function(a,b,c,d,e){var f=c.indexOf(a),g="",h="";0<f&&(f=c.indexOf(" "+a));!(a&&f+1)||e&&f||(f+=" "==c[f],g=eb(c.substr(0,f),b,d),h=eb(c.substr(0,f+a.length),b,d).substr(g.length));return[g,h,b.substr(g.length+h.length)]},eb=function(a,b,c){var d=a.length;for(a=a.split(" ").length;a--;)d+=
# (c[a]||0)-1;return b.substr(0,d+1)},bb=[],cb=/[\u0300-\u036f]+/g,db=/[\s\x00-/:-@[-`{-\u00bf\u2000-\u206f\u2e00-\u2e42\u3000-\u303f\uff00-\uff0f\uff1a-\uff20\uff3b-\uff40\uff5b-\uff65]+/g,gb=/^[\d\s]*[\u0590-\u08ff\ufb1d-\ufdff\ufe70-\ufefc]/;var hb=function(a,b,c,d,e,f,g){this.i=a;this.source=b;this.wa=c||"";this.g=d||"";this.H=e||[];this.kb=f||"";this.za=g||""},ib=function(a){var b=a.indexOf("|"),c=a.substr(0,b),d=K(c);a=a.substr(b+1);b=[];return new hb(a,0,"",K(a,b),b,c,d)},jb=function(a){var b=[];return new hb(a,2,"",K(a,b),b)};var kb=function(){this.Fa=100;this.A=0;this.G=this.D=null;this.T=Object.create(null)};kb.prototype.get=function(a){if(a=this.T[a])return lb(this,a),a.value};kb.prototype.set=function(a,b){var c=this.T[a];c?(c.value=b,lb(this,c)):(this.A>=this.Fa&&(delete this.T[this.G.key],this.G=this.G.F,this.G.V=null,--this.A),c=this.T[a]={key:a,value:b,V:this.D,F:null},this.D?this.D.F=c:this.G=c,this.D=c,++this.A)};var lb=function(a,b){var c=b.V,d=b.F;d&&((d.V=c)?c.F=d:a.G=d,a.D.F=b,b.V=a.D,b.F=null,a.D=b)};var mb=function(a,b,c){var d=new XMLHttpRequest;d.onreadystatechange=function(){4==d.readyState&&c(d.status,d.responseText)};d.open(b?"POST":"GET",a,!0);d.setRequestHeader("X-Requested-With","XHR");b&&d.setRequestHeader("Content-Type","application/x-www-form-urlencoded");b?d.send(b):d.send();return d},nb=function(a){a&&(a.onreadystatechange=ba,a.abort())};var ob=function(a,b){this.lb=a;this.Ca=b;this.N=this.K=0;this.la=this.ma="";this.na=void 0;this.ta=new kb},rb=function(a,b,c){var d=b?a.ta.get(pb(a,b,c)):[];d?a.Ca(b,c,d):(a.ma=b,a.la=c,10<=a.K||3<=a.N||(a.K?void 0!==a.na||(a.na=setTimeout(function(){qb(a)},100<<Math.max(a.K-4,0))):qb(a)))},qb=function(a){a.na=void 0;var b=a.ma,c=a.la;a.ma=a.la="";if(b){++a.K;var d=new XMLHttpRequest;d.onreadystatechange=function(){if(d&&4==d.readyState){var e=d.status;200==e&&a.ga(b,c,d.responseText);d=null;sb(a,
# e)}};d.ontimeout=function(){d&&(d=null,sb(a))};d.open("GET",pb(a,b,c),!0);d.timeout=3E4;d.send()}},sb=function(a,b){--a.K;var c=3*(403==b)+(499<b&&600>b);a.N+=c;c&&setTimeout(function(){a.N-=c},3E4)};ob.prototype.ga=function(a,b,c){try{var d=JSON.parse(c)}catch(g){}if(d&&"object"==typeof d&&(c=d.l,c instanceof Array)){d=[];for(var e=c.length,f=0;f<e;f++)d.push(ib(""+c[f]));this.ta.set(pb(this,a,b),d);this.Ca(a,b,d)}};
# var pb=function(a,b,c){return"/scholar_complete?"+encodeURIComponent(a.lb)+"="+encodeURIComponent(b)+"&"+c};var xb=function(a,b){var c=tb,d=wb;if(b||!(a in wb)){b=c&&c.getItem(a);if(b)try{var e=JSON.parse(b)}catch(f){}d[a]=e}return d[a]},yb=function(a,b){var c=tb;wb[a]=b;try{c&&c.setItem(a,JSON.stringify(b))}catch(d){}},wb={};try{var tb=window.localStorage}catch(a){};var Ab=function(a){this.Da="H:"+a;this.o=[];this.jb=.001*Date.now();a=xb(this.Da,void 0);a instanceof Array||(a=[]);for(var b=this.o,c={"":1},d=0;d<a.length&&50>b.length;d++){var e=new zb(a[d]);c.hasOwnProperty(e.g)||(c[e.g]=1,b.push(e))}};
# Ab.prototype.add=function(a,b,c){c=c||.001*Date.now();b=b||c;a=new zb([0,0,a]);if(a.g){for(var d=this.o,e=d.length,f=0;f<e&&d[f].g!=a.g;)++f;f<e||d.push(a);e=d[f];if(!(2>b-e.m)){e.m=b;e.i=a.i;e.H=a.H;for(e.w=Math.min(e.w+Bb(b),10*Bb(c));f&&Cb(d[f],d[f-1]);)a=d[f],d[f]=d[f-1],d[--f]=a;d.splice(50,1);Db(this)}}};Ab.prototype.remove=function(a){for(var b=this.o,c=b.length,d=0;d<c;d++)if(b[d].i==a){b.splice(d,1);Db(this);break}};
# var Db=function(a){for(var b=[],c=a.o,d=c.length,e=0;e<d;e++)b.push(c[e].encode());yb(a.Da,b)},Bb=function(a){return Math.exp(.0231*(Math.max(a-1422777600,0)/86400|0))},zb=function(a){a instanceof Array||(a=Eb);this.m=+a[0]||0;this.w=+a[1]||0;this.i=""+a[2];this.H=[];this.g=K(this.i,this.H,!0)};zb.prototype.encode=function(){return[this.m,this.w,this.i]};
# var Cb=function(a,b){var c=a.w-b.w;return 0<c||!c&&a.m>b.m},Eb=[0,0,""],Fb=function(a,b,c){this.m=a;this.w=b;this.i=c},Gb=function(a,b){var c=a.w-b.w;return 0<c||!c&&a.m>b.m};var Hb=function(a){this.j=a},Ib=function(a){var b=document.createElement("b");b.textContent=a;return b};var Jb=function(a,b,c){this.type=a;this.currentTarget=this.target=b;this.b=c||null;this.oa=!1};Jb.prototype.stopPropagation=function(){this.b&&this.b.stopPropagation();this.oa=!0};
# var L=function(a){a.b&&Ia(a.b);a.oa=!0},Lb=function(a,b,c){var d=Kb.pop();d?(Jb.call(d,a,b,c),a=d):a=new Jb(a,b,c);return a},Kb=[],M=function(a,b){this.ra=a;this.ib=b},Mb=function(a){this.ra=a},Nb=function(a,b){N(a,"click",b)},O=function(a,b){var c=b.length;if(c){var d=n(a),e=Ob[d];if(!e){e=Ob[d]=[];d=Pb(b[0].ra);for(var f in d){var g=Qb[f];g||(g=Qb[f]=Object.create(null));for(var h in d[f]){var l=g[h];l||(l=g[h]=[]);l.push(a)}}Rb(a,e,b[0],Sb);for(f=1;f<c;f++)Rb(a,e,b[f],Tb)}}},P=function(a,b,c){Ub(Lb(a,
# b,c))},N=function(a,b,c){var d=Vb;aa(b)&&(Wb[0]=b,b=Wb);var e=b.length;a=Pb(a);for(var f in a)for(var g in a[f])for(var h=0;h<e;h++)d(f,g,b[h],c)},Pb=function(a){aa(a)&&(Xb[0]=a,a=Xb);for(var b=a.length,c=Object.create(null),d=0;d<b;d++){var e=a[d],f=e.charAt(0),g=e.substr(1);if("#"!=f&&"."!=f||!g)throw Error("bad selector: "+e);(e=c[f])||(e=c[f]=Object.create(null));e[g]=!0}return c},Vb=function(a,b,c,d){var e=Yb[c];e||("touchstart"!=c&&"mouseover"!=c&&"mouseout"!=c&&B(document,c,Zb,"focus"==c||
# "blur"==c),e=Yb[c]=Object.create(null));(c=e[a])||(c=e[a]=Object.create(null));(a=c[b])||(a=c[b]=new A);a.add(d)},Zb=function(a){var b=a.target;b&&3==b.nodeType&&(b=b.parentNode);Ub(Lb(a.type,b,a))},Ub=function(a){for(var b=a.target;b&&b!=document&&!b.disabled&&!t(b,"gs_dis");){a.currentTarget=b;var c=b.id;if(c&&!$b("#",c,a))break;c=b.classList||[];for(var d=c.length,e=0;e<d;e++)if(!$b(".",c[e],a))return;b=b.parentNode}},$b=function(a,b,c){var d=Yb[c.type];(b=(a=d&&d[a])&&a[b])&&b.v(c);return!c.oa},
# Rb=function(a,b,c,d){var e=c.ra;c=c.ib;for(var f in c)N(e,f,ia(d,a,c[f])),b.push(new Mb(e))},Sb=function(a,b,c){var d=c.currentTarget;a=ac(a,d)||a;a=bc(a,d);b.call(a,c)},Tb=function(a,b,c){a:{for(var d=c.currentTarget;d&&d!=document;){var e=ac(a,d);if(e){a=bc(e,d);break a}d=d.parentNode}a=void 0}a&&b.call(a,c)},bc=function(a,b){var c=cc(b),d=dc[c];d||(d=dc[c]=[]);for(var e=d.length,f=0;f<e;f++){var g=d[f];if(g instanceof a)return g}b=new a(b);d.push(b);a=n(a);(d=ec[a])||(d=ec[a]=[]);d.push(c);return b},
# ac=function(a,b){var c,d=b.id;d&&(c=fc(a,c,"#",d));b=b.classList||[];d=b.length;for(var e=0;e<d;e++)c=fc(a,c,".",b[e]);return c},fc=function(a,b,c,d){c=(d=(c=Qb[c])&&c[d])?d.length:0;for(var e=0;e<c;e++){var f=d[e];!(f===a||f.prototype instanceof a)||b&&!(f===b||f.prototype instanceof b)||(b=f)}return b},cc=function(a){var b=a.getAttribute("data-duid");b||a.setAttribute("data-duid",b=""+gc++);return b},Yb=Object.create(null),Xb=[""],Wb=[""],Qb=Object.create(null),Ob=Object.create(null),ec=Object.create(null),
# dc=Object.create(null),gc=100;window.gs_evt_dsp=Zb;var hc=function(a){if(aa(a)){var b=a.charAt(0),c=a.slice(1);if("#"==b)a=function(a){return a.id==c&&0<a.offsetWidth};else if("."==b)a=function(a){return t(a,c)&&0<a.offsetWidth};else throw Error("bad selector: "+a);}return a},jc=function(a,b,c,d){return ic(a,b,hc(c),!!d,!1)},ic=function(a,b,c,d,e){for(var f;b&&a;){if(c(b)){if(e)return b}else for(f=b&&(d?b.lastElementChild:b.firstElementChild);f;f=f&&(d?f.previousElementSibling:f.nextElementSibling))if(e=ic(f,f,c,d,!0))return e;for(e=!0;;){if(b==a)return null;
# f=b.parentNode;if(b=b&&(d?b.previousElementSibling:b.nextElementSibling))break;b=f}}return null};var Q=function(a){var b=this;this.a=a.querySelector(".gs_in_ac");this.j=a.querySelector(".gs_md_ac");this.J=this.C=!1;this.o=new Ab(this.a.name);this.Ia=new ob(this.a.name,function(a,d,e){d==b.X&&kc(b,a)&&(a.length>=b.Y.length||!kc(b,b.Y))&&(b.Y=a,b.pa=e,lc(b))});this.Aa=0;this.mb=new Hb(this.j);this.xa=[];this.ya=[];this.Y="";this.pa=[];this.X="";this.B=this.a.value;mc(this);B(this.a.form,["change","gs-change"],function(){mc(b)})},nc=function(a){return"block"==a.j.style.display},pc=function(a){if(nc(a)){var b=
# oc(a);b&&q(b,"gs_sel");a.C=a.J=!1;a.j.style.display="none"}},qc=function(a,b,c){a.xa=c||[];c=a.o;var d=K(b);var e=" "+d,f=d.length,g=d.split(" ").length,h=.1/Bb(c.jb),l=c.o,y=l.length;c=[];for(var m=0;m<y;m++){var x=l[m],r=x.g,D=r.indexOf(d);if(!(0>D)){var G=10;D&&(D=r.lastIndexOf(e),G=+(0<=D));r=G*(2*(g-1)+(1+(" "==(r[D+f]||" "))))/g;D=x.w*h;if(r=d?r*D:1){x=new Fb(x.m,r,x.i);for(r=0;r<c.length&&!Gb(x,c[r]);)++r;3>r&&c.splice(r,0,x);c.splice(3,1)}}}d=[];for(e=0;e<c.length;e++)d.push(jb(c[e].i));a.ya=
# d;rb(a.Ia,b,a.X);lc(a)},kc=function(a,b){return 0==K(a.a.value).indexOf(K(b))},rc=function(a){var b=a.a.value;a.B=b;mc(a);var c=[],d=a.a.getAttribute("data-iq")||"",e=a.a.getAttribute("data-is");if(d==b&&e){d=document.querySelectorAll(e);e=d.length;for(var f=0;f<e&&10>f;f++){var g=d[f];c.push(new hb(g.textContent,1,g.innerHTML))}}qc(a,b,c)},lc=function(a){a.Aa++||Ha(function(){a.Aa=0;var b=a.xa;var c=a.pa;if(b.length)b=b.slice(0,10);else{b=a.ya.slice(0,3);var d=c.length&&c[0].za,e=d?3:10,f=b.length;
# if(!f||!d){for(d=Object.create(null);f--;)d[b[f].g]=!0;for(f=0;f<c.length&&b.length<e;f++){var g=c[f];d[g.g]||b.push(g)}}}c=b;var h=a.a.value,l=a.mb.j.firstElementChild;g=l.querySelector(".gs_md_acs");b=l.querySelector("ul");e=(e=b.querySelector(".gs_sel"))?e.getAttribute("data-q"):"";f=c.length;var y=[];d=K(h,y);b.innerHTML="";if(f){var m=c[0].za,x=m&&"gs_md_acp";aa(x)||(x=x.join(" "));l.className!=x&&(l.className=x);h=fb(m,h,d,y,!0);g.textContent=h[0]+h[1];h=h[2];d=K(h,y);for(g=0;g<f;g++){m=c[g];
# l=document.createElement("li");y=(m.kb||"")+m.i;l.className="gs_md_ac_li";l.setAttribute("data-q",y);l.setAttribute("onclick","");if(m.wa)l.innerHTML=m.wa;else{h=fb(d,m.i,m.g,m.H);if(!h[1]){for(h=0;m.g[h]==d[h];)++h;h=fb(d.substr(0,h),m.i,m.g,m.H)}h[0]&&l.appendChild(Ib(h[0]));l.appendChild(document.createTextNode(h[1]));h[2]&&l.appendChild(Ib(h[2]));2==m.source&&(p(l,"gs_md_ac_lh"),h=document.createElement("span"),h.className="gs_ico gs_ico_X gs_ico_Xt",l.appendChild(h))}y==e&&p(l,"gs_sel");b.appendChild(l)}}c=
# c.length&&document.activeElement==a.a;c!=nc(a)&&(c?nc(a)||(a.C=a.J=!1,a.j.style.display="block"):pc(a))})},oc=function(a){return a.j.querySelector(".gs_sel")},tc=function(a,b){var c=a.a.getAttribute("data-oq")||"oq",d=a.a.form,e=d.elements[c];e||(e=document.createElement("input"),e.name=c,e.type="hidden",d.appendChild(e));e.value=a.B;a.a.value=sc(b)},uc=function(a){P("gs-change",a.a)};k=Q.prototype;k.Ya=function(){var a=this.a.value;this.B!=a&&(this.B=a,qc(this,a),vc(this.a,K(a).match(gb)?"rtl":"ltr"))};
# k.ea=function(a){if(!this.J){var b=a.b,c=b.keyCode;b=Ja(b);var d;13!=c||b?27!=c||b?38!=c&&40!=c||b?(46==c&&!b||88==c&&(1==b||4==b))&&(d=oc(this))&&t(d,"gs_md_ac_lh")&&(this.a.selectionStart||0)>=this.a.value.length&&(this.o.remove(sc(d)),qc(this,this.a.value=this.B),L(a),uc(this)):(nc(this)?((d=oc(this))&&q(d,"gs_sel"),(d=jc(this.j,d||this.j,".gs_md_ac_li",38==c))?(p(d,"gs_sel"),this.a.value=sc(d)):this.a.value=this.B,uc(this)):rc(this),L(a)):nc(this)&&(this.a.value=this.B,pc(this),L(a),uc(this)):
# ((d=oc(this))&&tc(this,d),pc(this),uc(this))}};k.fa=function(){if(document.activeElement==this.a)rc(this);else{clearTimeout(this.ka);var a=this;this.ka=setTimeout(function(){a.ka=void 0},500)}};k.Xa=function(){void 0!==this.ka&&rc(this)};k.La=function(){var a=this;setTimeout(function(){pc(a)},this.C?300:0)};k.Ka=function(a){this.C&&L(a)};k.Va=function(){this.J=!0};k.Ua=function(){this.J=!1};var mc=function(a){var b=a.a,c=ua(b.form,function(a){return a!=b});c!=a.X&&(a.X=c,a.Y="",a.pa=[])};k=Q.prototype;
# k.Pa=function(a){this.C=!0;L(a)};k.Qa=function(){this.C=!0};k.ca=function(){this.C=!1};k.Ma=function(a){var b=a.currentTarget;if(t(a.target,"gs_ico_X"))this.o.remove(sc(b)),qc(this,this.a.value=this.B);else{tc(this,b);pc(this);this.a.blur();var c=this.a.form;setTimeout(function(){c.submit()},0)}uc(this)};k.Oa=function(a){a=a.currentTarget;if(!t(a,"gs_sel")){var b=oc(this);b&&q(b,"gs_sel");p(a,"gs_sel")}};k.Na=function(a){q(a.currentTarget,"gs_sel")};
# var wc=[new M(".gs_in_acw",{}),new M(".gs_in_ac",{input:Q.prototype.Ya,keydown:Q.prototype.ea,mousedown:Q.prototype.fa,focus:Q.prototype.Xa,blur:Q.prototype.La,beforedeactivate:Q.prototype.Ka,compositionstart:Q.prototype.Va,compositionend:Q.prototype.Ua}),new M(".gs_md_ac",{mousedown:Q.prototype.Pa,touchstart:Q.prototype.Qa,mouseup:Q.prototype.ca,touchend:Q.prototype.ca,touchcancel:Q.prototype.ca}),new M(".gs_md_ac_li",{click:Q.prototype.Ma,mouseover:Q.prototype.Oa,mouseout:Q.prototype.Na})],sc=function(a){return a.getAttribute("data-q")||
# ""},vc=function(a,b){a.getAttribute("dir")!=b&&(a.setAttribute("dir",b),a.parentNode.setAttribute("dir",b),a.parentNode.querySelector(".gs_md_ac").setAttribute("dir",b))},xc=function(){for(var a=document.querySelectorAll(".gs_in_ac"),b=a.length,c=0;c<b;c++){var d=a[c],e=d.getAttribute("data-iq")||"";d.value=e;vc(d,K(e).match(gb)?"rtl":"ltr");P("gs-change",d);e=d.getAttribute("data-oq")||"oq";(e=d.form.elements[e])&&d.form.removeChild(e)}};var yc=function(a){return!!t(a,"gs_sel")+2*!!t(a,"gs_par")},zc=["false","true","mixed"];var Ac=function(a){var b=window;function c(){d.Ba=0;d.f.v()}this.f=new A;this.Ba=0;this.sa=[b,a,function(){d.Ba++||Ha(c)},!1];var d=this};Ac.prototype.addListener=function(a){this.f.A||B.apply(null,this.sa);this.f.add(a)};Ac.prototype.removeListener=function(a){this.f.remove(a);this.f.A||C.apply(null,this.sa)};var Bc=new Ac("scroll"),Cc=new Ac("resize");var Dc=new A,Ec=function(){var a=document.documentElement,b=oa();b={gs_el_ph:1==b,gs_el_ta:2==b,gs_el_sm:4!=b,gs_el_tc:pa||1==b};var c;for(c in b){var d=b[c];if(t(a,c)!=d){var e=!0;u(a,c,d)}}e&&Dc.v()};u(document.documentElement,"gs_el_ios",ma);Ec();Cc.addListener(Ec);B(window,["pageshow","load"],Ec);var Fc,Gc=function(a){return"object"==typeof a?a:null},Lc=function(a,b){b=Hc(b);a=Ic(a);a=Jc(a)||"#";Fc=Gc(b);Kc?window.history.pushState(b,"",a):window.location.assign(a)},Mc=function(a,b){b=Hc(b);a=Ic(a);a=Jc(a)||"#";Fc=Gc(b);Kc?window.history.replaceState(b,"",a):window.location.replace(a)},Jc=function(a){var b=[],c;for(c in a)b.push(encodeURIComponent(c)+"="+encodeURIComponent(a[c]));return(a=b.sort().join("&"))?"#"+a:""},Nc=function(a){var b={};a=a.split("&");for(var c=0;c<a.length;c++){var d=
# a[c],e=d.indexOf("=");if(e+1){var f=d.substr(0,e);d=d.substr(e+1)}else f=d,d="";f&&(b[decodeURIComponent(f)]=decodeURIComponent(d))}return b},Oc=function(){var a=window.location.hash,b=a.indexOf("#")+1;return Nc(b?a.substr(b):"")},Pc=function(a,b){for(var c in b){var d=b[c];void 0!==d?a[c]=d:delete a[c]}},Ic=function(a){var b=Oc();Pc(b,a);return b},Hc=function(a){var b=Fc||Gc(window.history.state),c={},d;for(d in b)c[d]=b[d];Pc(c,a);return c},Tc=function(){setTimeout(function(){if(!Qc){var a=window.history.state;
# Qc=!0;Fc=Gc(a);Rc.v()}Sc=!1},0)},Rc=new A,Qc=!1,Sc=!0,Kc="pushState"in window.history;"onpageshow"in window?B(window,"pageshow",Tc):E(Tc);B(window,Kc?"popstate":"hashchange",function(a){"loading"!=document.readyState&&(a=a.state,Qc=!0,Fc=Gc(a),Rc.v())});var hd=function(a,b,c,d){function e(){var a=D&&t(g,"gs_el_ph");u(x,"gs_vis",!a);g.style.overflowY=Zd&&!a?"scroll":""}function f(){var a=g.clientHeight,b=+r.getAttribute("data-h");b||(y.style.maxHeight="none",b=l.offsetHeight);b=Math.max((a-b)/2,10);a=Math.max(a-48-2*b,10);var c=D&&t(g,"gs_el_ph");l.style.top=c?"auto":b+"px";y.style.maxHeight=c?"none":a+"px";Uc(y)}var g=document.documentElement,h=w("gs_top"),l=w(a),y=w(a+"-bdy"),m=Vc(l),x=w(l.getAttribute("data-shd")||"gs_md_s"),r=Wc(l),D=!!r&&t(r,
# "gs_md_wmw"),G=window.pageYOffset,Zd=h.scrollHeight>g.clientHeight,ub=!!F[a],vb=ub?"":R,ea=b||"",Ma=c||"";b=d||"";c=ea&&"#"!=ea[0]&&!b;d=a==R&&ea==Xc&&Ma==S;c?(ub?u(m,"gs_md_ldg",!0):Yc(l,m,'<div class="gs_md_prg">'+w("gs_md_ldg").innerHTML+"</div>"),P("gs-md-ldin",m)):(b&&Yc(l,m,b),P("gs-md-lded",m));vb&&(++Zc,I(vb),--Zc);R=a;Xc=ea;S=Ma;$c=b;d||Zc||(ad+=1,(vb?Mc:Lc)(bd(),cd()));ub||Sa(l,function(){r&&p(r,"gs_vis");p(l,"gs_vis");u(l,"gs_abt",Sc);dd(a);Dc.add(e);e();r&&y&&(f(),Cc.addListener(f));p(h,
# "gs_nscl");h.style.top=-G+"px"},function(){Dc.remove(e);Cc.removeListener(f);r&&q(r,"gs_vis");q(l,"gs_vis");q(l,"gs_abt");q(x,"gs_vis");g.style.overflowY="";q(h,"gs_nscl");h.style.top="auto";nb(T);T=null;window.scrollTo(0,G);R=Xc=S=$c="";var a=ad;ad=0;Zc||(0<a?window.history.go(-a):Mc(bd(),cd()))},ed(l),fd(l));c&&(nb(T),T=null,T=mb(ea,Ma,function(b,c){T=null;b=200==b;Yc(l,m,b?c:gd());b&&a==R&&ea==Xc&&Ma==S&&($c=c,Mc(bd(),cd()));P("gs-md-lded",m)}))},Wc=function(a){a=a.parentNode;return t(a,"gs_md_wnw")?
# a:null},ed=function(a){return(a=a.getAttribute("data-ifc"))?w(a):null},fd=function(a){return(a=a.getAttribute("data-cfc"))?w(a):null},Vc=function(a){return w(a.getAttribute("data-cid")||a.id+"-bdy")||a},Yc=function(a,b,c){u(b,"gs_md_ldg",!1);for(var d=b.querySelectorAll("[data-duid]"),e=d.length,f={},g=0;g<e;g++){for(var h=cc(d[g]),l=dc[h],y=l?l.length:0,m=0;m<y;m++){var x=l[m],r=n(x.constructor),D=f[r];D||(D=f[r]={});D[h]=!0;x&&"function"==typeof x.ua&&x.ua()}delete dc[h]}for(var G in f){G=+G;d=
# f[G];g=(e=ec[G])?e.length:0;for(l=h=0;l<g;l++)y=e[l],y in d||(e[h++]=y);h?e.length=h:delete ec[G]}b.innerHTML=c;dd(a.id);nb(T);T=null},dd=function(a){if(a=document.querySelector("#"+a+">.gs_md_bdy"))a.scrollTop=a.scrollLeft=0,Uc(a)},Uc=function(a){var b=a.style,c="padding"+("rtl"==ta(a||document.body).direction?"Left":"Right");b[c]="";var d=a.offsetWidth-a.clientWidth;2<d&&(a=parseInt(window.getComputedStyle(a,null)[c],10)||0,b[c]=Math.max(a-d,0)+"px")},id=function(){return w("gs_md_err").innerHTML},
# gd=function(){return'<div class="gs_md_prg"><div class="gs_alrt">'+id()+"</div></div>"},bd=function(){return{d:R||void 0,u:Xc||void 0,p:S?"1":void 0}},cd=function(){return{n:ad,p:S,h:$c}},T=null,R="",Xc="",S="",$c="",ad=0,Zc=0;Rc.add(function(){var a=Oc(),b=a.d||"",c=b?w(b):null;++Zc;if(c){c=a.u||"";a=0<+a.p;var d=Fc||Gc(window.history.state)||{},e=+d.n||0,f=""+(d.p||"");d=""+(d.h||"");c.match(za)||(c="");a!=!!f?hd(b,"","",gd()):b==R&&c==Xc&&f==S&&d==$c||hd(b,c,f,d);ad=e}else R&&I(R);--Zc});var U=function(a){ka.call(this);this.S=a;this.ha=Object.create(null);this.P=null;a=a.querySelectorAll(".gs_in_txtw>input[type=text]");for(var b=a.length;b--;){var c=a[b],d=c.parentNode.querySelector(".gs_in_txts");c=c.name;d&&c&&(this.ha[c]=d.innerHTML)}};ja(U,ka);U.prototype.$=function(){nb(this.P);this.S=this.P=null;U.ob.$.call(this)};U.prototype.eb=function(a){L(a);if((a=this.S)&&!this.P){var b="json=&"+ua(a),c=this;jd(this,!0);this.P=mb(a.action,b,function(a,b){c.ga(a,b)})}};
# U.prototype.ga=function(a,b){this.P=null;jd(this,!1);var c=this.S,d=c.getAttribute("data-alrt");if(d=d?w(d):null)d.innerHTML="";try{var e=200==a&&JSON.parse(b)}catch(y){}e&&"object"==typeof e||(e=id(),d?d.innerHTML=e:Ya(e),e={});if(a=e.L)xa(""+a);else{if(a=e.M)d?d.innerHTML=a:Ya(a);a=1E6;if(d&&d.innerHTML){var f=d;a=d.getBoundingClientRect().top}c=c.elements;e=e.E;"object"==typeof e||(e=Object.create(null));for(var g in this.ha){d=c[g];var h;b=""+(e[g]||"");var l=d.parentNode.querySelector(".gs_in_txts");
# u(d.parentNode,"gs_in_txte",!!b);l&&(l.innerHTML=b||this.ha[g]||"");b&&(h=d.getBoundingClientRect().top)<a&&(f=d,a=h)}f&&f.scrollIntoView&&(0>a||a+20>window.innerHeight)&&f.scrollIntoView()}};var jd=function(a,b){a=a.S;var c=a.getAttribute("data-bsel");a=c?document.querySelectorAll(c):a.querySelectorAll("button");for(c=a.length;c--;){var d=a[c];d.disabled=b;u(d,"gs_bsp",b)}};O(U,[new M(".gs_ajax_frm",{submit:U.prototype.eb})]);var kd=[[1,0,1],[2,0,1]];N(".gs_cb_gen","click",function(a){var b=a.currentTarget,c=yc(b),d=2==+b.getAttribute("data-s");c=kd[+d][c];u(b,"gs_sel",1==c);u(b,"gs_par",2==c);b.setAttribute("aria-checked",zc[c]);P("gs-change",b,a.b)});N(".gs_cb_gen",["keydown","keyup"],function(a){var b=a.currentTarget,c=a.b.keyCode;"BUTTON"!=b.tagName||13!=c&&32!=c||(L(a),"keydown"==a.type&&b.click())});N([".gs_cb_gen",".gs_md_li"],"keydown",function(a){var b=a.currentTarget,c=b.tagName,d=a.b.keyCode;"BUTTON"!=c&&(32==d||13==d&&"A"!=c)&&(L(a),b.click())});var ld=["click","contextmenu","mouseup"].concat(navigator.sendBeacon&&GSP.neverBounce?[]:["mousedown","touchstart"]),md=GSP.bouncePrefix||"http://"+window.location.host,nd="",od=null,pd=function(){od=null},qd=function(a){navigator.sendBeacon?navigator.sendBeacon(a):od&&a==od.src||((od=new Image).src=a,setTimeout(pd,1E3))},rd=function(){var a=document.location.href,b=a.indexOf("?")+1;a=b?a.substr(b):"";b=a.indexOf("#");a=Nc(b+1?a.substr(0,b):a).hl||"";a="/scholar_bfnav?url="+encodeURIComponent(document.location.href)+
# "&hl="+encodeURIComponent(a)+"&ei="+GSP.eventId;qd(a)};E(function(){nd=Za()?"&bn=1":"";Za()&&rd()});B(window,"pageshow",function(a){a.persisted&&(nd="&bn=1",rd())});
# B(document,ld,function(a){if(!("click"==a.type&&a.button||"mouseup"==a.type&&1!=a.button)){a=a.target;for(var b,c,d,e;a;){b=a.nodeName;if("A"==b&&(c=a.getAttribute("href"))&&(d=a.getAttribute("data-clk"))){e="/scholar_url?url="+encodeURIComponent(c)+"&"+d+"&ws="+window.innerWidth+"x"+window.innerHeight+"&at=";var f=encodeURIComponent,g=a.getAttribute("data-clk-atid");g=g&&w(g);e=e+f(g&&g.innerText||"")+nd;0<d.indexOf("scisig=")?(a.setAttribute("href",md+e),a.removeAttribute("data-clk")):qd(e)}a=("SPAN"==
# b||"B"==b||"I"==b||"EM"==b)&&a.parentNode}}},!1,!0);N(".gs_fm_s","click",function(a){a=a.currentTarget.getAttribute("data-fm")||"";(a=w(a))&&a.submit()});var V=function(a){this.I=z(a.querySelector(".gs_md_d"));this.Z=z(a.querySelector(".gs_md_tb"))};k=V.prototype;k.ba=function(a){var b=w(this.I);return void 0!==a?jc(b,b,".gs_md_li",a):null};k.open=function(a){a=this.ba(a);if(t(w(this.Z),"gs_sel"))try{a&&a.focus()}catch(c){}else{var b=w(this.Z);Ta(this.I,function(){p(b,"gs_sel")},function(){q(b,"gs_sel")},a,b)}};k.close=function(){I(this.I)};k.Ra=function(a){L(a);t(w(this.Z),"gs_sel")?this.close():this.open("keydown"==a.b.type?!1:void 0)};
# k.va=function(a){var b=a.b.keyCode;if(38==b||40==b)L(a),this.open(38==b)};k.Wa=function(a){a.target.id==this.I&&this.va(a)};O(V,[new M(".gs_md_rmb",{}),new M(".gs_md_tb",{"gs-press":V.prototype.Ra,keydown:V.prototype.va}),new M(".gs_md_d",{keydown:V.prototype.Wa})]);var W=function(a){V.call(this,a);this.gb=z(a.querySelector(".gs_md_in"));this.hb=z(a.querySelector(".gs_md_tb .gs_lbl"))};ja(W,V);W.prototype.ba=function(){return w(this.I).querySelector(".gs_md_li[aria-selected]")};W.prototype.Za=function(a){sd(this,a)};W.prototype.da=function(a){var b=a.b.keyCode;13!=b&&32!=b||sd(this,a)};
# var sd=function(a,b){var c=b.currentTarget,d=w(a.gb),e=a.ba();c!=e&&(d.value=c.getAttribute("data-v"),w(a.hb).innerHTML=c.innerHTML,e&&td(e,!1),td(c,!0));L(b);a.close();P("gs-change",d,b.b)},td=function(a,b){u(a,"gs_sel",b);b?a.setAttribute("aria-selected","true"):a.removeAttribute("aria-selected")};O(W,[new M(".gs_md_ris",{}),new M(".gs_md_li",{click:W.prototype.Za,keydown:W.prototype.da})]);N("#gs_lp","click",function(a){L(a);hd("gs_lp_d")});N("#gs_lp_cur","click",function(a){L(a);I("gs_lp_d")});var ud=function(a){this.Ea=z(a)};
# ud.prototype.da=function(a){var b=a.currentTarget,c=a.b.keyCode;if(38==c||40==c){var d=w(this.Ea);d=jc(d,b,".gs_md_li",38==c)||jc(d,d,".gs_md_li",38==c)}else if(37==c||39==c)a:{c=!!(37==c^"rtl"==ta(b.parentNode||document.body).direction);var e=b.parentNode,f=e.children;d=f.length;if(e.id!=this.Ea){for(;f[--d]!=b;);(f=e&&(c?e.previousElementSibling:e.nextElementSibling))||(f=(e=e.parentNode)&&(c?e.lastElementChild:e.firstElementChild));f=f.children;if(d=Math.min(d+1,f.length))if(e=f[d-1],t(e,"gs_md_li")&&
# e.offsetLeft!=b.offsetLeft){d=e;break a}}d=void 0}d&&(L(a),d.focus())};O(ud,[new M(".gs_md_ulr",{}),new M(".gs_md_li",{keydown:ud.prototype.da})]);N("#gs_hdr_mnu","click",function(a){L(a);hd("gs_hdr_drw")});N("#gs_hdr_drw_mnu","click",function(a){L(a);I("gs_hdr_drw")});N("#gs_hdr_act_i","click",function(a){L(a);1==oa()?xa(document.querySelector("#gs_hdr_drw_bot>a").href):Ta("gs_hdr_act_d")});N("#gs_hdr_drw","keydown",function(a){var b=a.b.keyCode;if(38==b||40==b){var c=a.currentTarget;if(b=jc(c,c,".gs_md_li",38==b))L(a),b.focus()}});
# N("#gs_hdr_tsi",["focus","blur"],function(a){function b(){var a=d.getBoundingClientRect().top-10;10<Math.abs(a)&&window.scrollBy(0,a);clearTimeout(e);c()}function c(){C(window,f,b)}var d=a.target;a="focus"==a.type;u(w("gs_hdr"),"gs_hdr_ifc",a);if(a&&pa&&!(749<window.innerHeight)){var e=setTimeout(c,1E3),f=["scroll","resize"];B(window,f,b)}});N("#gs_hdr_tsi",["input","gs-change"],function(a){u(w("gs_hdr_frm"),"gs_hdr_tsc",!!a.currentTarget.value)});
# N("#gs_hdr_tsc","mousedown",function(a){L(a);var b=w("gs_hdr_tsi");b.value="";b.focus();P("input",b,a.b)});N("#gs_hdr_sre","click",function(a){L(a);var b=w("gs_hdr");Ta("gs_hdr_frm",function(){q(b,"gs_hdr_src");p(b,"gs_hdr_srx")},function(){p(b,"gs_hdr_src");q(b,"gs_hdr_srx")},w("gs_hdr_tsi"))});N(".gs_md_x","click",function(a){(a=a.currentTarget.getAttribute("data-mdx"))&&I(a)});var X=function(){},vd,wd;k=X.prototype;k.Ta=function(a){a.b.button||(L(a),xd(a))};k.ea=function(a){yd(a)&&(L(a),xd(a))};k.$a=function(a){yd(a)&&L(a)};k.fa=function(a){if(!a.b.button){L(a);var b=a.b;b&&(zd=b.clientX||0,Ad=b.clientY||0,B(document,Bd,Cd,!0),clearTimeout(vd),vd=setTimeout(Dd,2E3));xd(a)}};k.fb=function(a){L(a);if(Ed){var b=a.b;if(b=(b=b&&b.touches)&&1==b.length&&b[0])Fd=b.clientX,Gd=b.clientY,B(document,Hd,Id,!0),clearTimeout(wd),wd=setTimeout(Jd,2E3)}xd(a)};
# var yd=function(a){a=a.b.keyCode;return 32==a||13==a},xd=function(a){P("gs-press",a.currentTarget,a.b)},Dd=function(){C(document,Bd,Cd,!0);clearTimeout(vd);vd=void 0},Cd=function(a){"mousedown"!=a.type&&10>Math.abs(a.clientX-zd)&&10>Math.abs(a.clientY-Ad)?(Ia(a),"click"==a.type&&Dd()):Dd()},Jd=function(){C(document,Hd,Id,!0);clearTimeout(wd);wd=void 0},Id=function(a){"touchstart"!=a.type&&10>Math.abs(a.clientX-Fd)&&10>Math.abs(a.clientY-Gd)?(Ia(a),"click"==a.type&&Jd()):Jd()},zd=0,Ad=0,Bd=["mousedown",
# "mouseup","click"],Ed=v("Android")&&!v("Chrome"),Fd=0,Gd=0,Hd=["touchstart","mousedown","mouseup","click"];O(X,[new M(".gs_press",{click:X.prototype.Ta,keydown:X.prototype.ea,keyup:X.prototype.$a,mousedown:X.prototype.fa,touchstart:X.prototype.fb})]);var Kd,Ld,Md,Qd=function(){var a=0>Ld.getBoundingClientRect().top;Nd!=a&&(Nd=a,u(Kd,"gs_sth_vis",a),a?Od():(Md.style.left="",Md.style.width="",Pd()))},Od=function(){if(Nd){var a=Ld.getBoundingClientRect();Md.style.left=a.left+"px";Md.style.width=a.width+"px";Pd()}},Pd=function(){P("gs-sth-change",w("gs_sth"))},Nd=!1;E(function(){if(Kd=w("gs_sth"))Ld=Kd.querySelector(".gs_sth_g"),Md=Kd.querySelector(".gs_sth_b"),Bc.addListener(Qd),Cc.addListener(Od),Qd()});var Rd=function(){w("gs_asd_frm").submit()};var Sd,Td=function(a,b,c){var d=(w("gs_citd").getAttribute("data-u")||"").replace("{id}",a).replace("{p}",""+b);mb(d,"",function(a,b){F.gs_cit||(200==a?hd("gs_cit",d,"",b):Ya(id()));c&&c()})};var Ud=function(){Nb("#gsb_promo_x",function(a){w("gsb_promo").className="";L(a);mb(a.target.href,"",function(){})});B(window,"message",function(a){var b=a.data,c;a.origin.match(/[.]google[.]com(:[0-9]+)?$/)&&b&&"object"==typeof b&&0<=(c=+b.gsbPromo)&&(w("gsb_promo").className=c?"gsb_not_installed":"gsb_installed")});E(function(){var a=document.createElement("iframe");a.id="gsb_promo_ping";a.frameBorder="0";a.scrolling="no";a.tabIndex=-1;a.src=(window.location.host.indexOf("scholar.google.")?"":"//scholar.google.com")+
# "/scholar_gsb_promo_ping";document.body.appendChild(a)})};var Y=function(a){var b=w("gs_res_glb");return b?b.getAttribute(a)||"":""};var Yd=function(a,b){if(!Vd[a]){Vd[a]=!0;Wd.v({aa:a,ia:b,error:void 0});var c=Y("data-lpu");c=b?Y("data-tra").replace("{id}",c+":"+b):Y("data-sva").replace("{id}",a);mb(c,"",function(c,e){delete Vd[a];var d=b,g="";if(200==c)try{var h=JSON.parse(e)}catch(l){}da(h)?h.L?xa(""+h.L):h.M?g=""+h.M:"array"==ca(h.U)&&1==h.U.length&&da(h.U[0])?(c=(""+(h.U[0].c||"")).split(":"),d=c[1]||"",e={},e[a+","+c[0]]=d,Xd(e)):g=id():g=id();Wd.v({aa:a,ia:d,error:g})})}},$d=function(a){return(a=xb("s",a))&&da(a)?a:{}},
# Xd=function(a){var b=Date.now(),c=$d(!0),d;for(d in c){var e=c[d];e instanceof Array&&2==e.length&&12E5>b-e[1]||delete c[d]}for(var f in a)c[f]=[a[f],b];yb("s",c)},Vd={},Wd=new A;var Z=function(a){this.qa=a;this.Ga=a.getAttribute("data-cid")||"";this.Ha=ae(a);this.nb=+(a.getAttribute("data-rp")||0)||0};Z.prototype.ab=function(a){u(a.currentTarget.parentNode,"gs_or_mvi")};Z.prototype.Sa=function(a){var b=a.currentTarget;t(b,"gs_or_ldg")||(u(b,"gs_or_ldg",!0),Td(this.Ga,this.nb,function(){u(b,"gs_or_ldg",!1)}))};Z.prototype.Ja=function(a){var b=a.currentTarget,c=b.parentNode;Ta(z(b),function(){q(b,"gs_press");p(c,"gs_vis");p(b,"gs_anm")},function(){p(b,"gs_press");q(c,"gs_vis")})};
# Z.prototype.cb=function(){var a=this.qa.getAttribute("data-lid")||"";Yd(this.Ha,a)};
# var be=[new M(".gs_or",{}),new M(".gs_or_ggsm",{"gs-press":Z.prototype.Ja}),new M(".gs_or_cit",{click:Z.prototype.Sa}),new M(".gs_or_sav",{click:Z.prototype.cb}),new M(".gs_or_mor",{click:Z.prototype.ab})],ce=function(){for(var a=t(document.documentElement,"gs_el_ph"),b=document.querySelectorAll(".gs_or_ggsm"),c=b.length;c--;){var d=b[c];t(d,"gs_vis")&&I(z(d));u(d,"gs_press",a);q(d,"gs_anm")}},de=function(a){var b=document.querySelector('.gs_or[data-did="'+a.aa+'"]');if(b){var c=b.querySelector(".gs_or_sav");
# c&&(u(c,"gs_or_ldg",void 0===a.error),a.error?Ya(a.error):b.setAttribute("data-lid",a.ia))}},ae=function(a){return a.getAttribute("data-did")||""};var ee,fe,ge=function(a){this.qa=a};ge.prototype.bb=function(){ee=ae(this.qa);fe=Date.now()};
# var he=function(){var a=document.location.href;return a.substr(0,a.indexOf("#"))||a},ie=function(){return document.querySelector(".gs_r_rfr")},je=function(a){var b=ie();return!!b&&ae(b)==a&&!!b.querySelector(".gs_rfr")},ke=function(){var a=xb("rfr",void 0);return a&&da(a)?a:null},me=function(a,b,c){p(a,"gs_r_rfr");var d=document.createElement("div");d.className="gs_rfr";d.innerHTML=b;a.appendChild(d);if(c){b="@keyframes gs_r_vsld_anm{0%{transform:translate(0,-"+d.offsetHeight+"px);}100%{transform:translate(0,0);}}";
# c=w("gs_r_vsld_style");c||(c=document.createElement("style"),c.id="gs_r_vsld_style",document.head.appendChild(c));c.textContent=b;for(b=a.nextElementSibling;b;)p(b,"gs_r_vsld"),b=b.nextElementSibling;(b=w("gs_res_ccl_bot"))&&p(b,"gs_r_vsld");p(a,"gs_anm");Ga(d,"animationend",le,500,le)}},le=function(){var a=ie();a&&q(a,"gs_anm");a=document.querySelectorAll(".gs_r_vsld");for(var b=a.length,c=0;c<b;c++)q(a[c],"gs_r_vsld")},ne=function(){var a=ie();if(!a)return!1;q(a,"gs_r_rfr");var b=a.querySelector(".gs_rfr");
# if(!b)return!1;a.removeChild(b);return!0},oe=function(){var a=window.pageYOffset,b=ie();if(!b)return a;b=b.querySelector(".gs_rfr");if(!b)return a;b=b.getBoundingClientRect();0>b.top&&(a-=b.bottom-b.top);return a},pe=[new M([".gs_r"],{}),new M([".gs_rt",".gs_or_ggsm"],{click:ge.prototype.bb})];GSP.customAC&&(O(Q,wc),E(xc),B(window,"pageshow",function(){setTimeout(xc,0)}));N("#gs_asd_psb","click",Rd);N("#gs_asd_frm","keydown",function(a){var b=a.target;"INPUT"==b.tagName&&"text"==b.type&&13==a.b.keyCode&&Rd()});N(".gs_citr","focus",function(a){var b=a.currentTarget;b!=Sd&&(Sd=b,L(a),setTimeout(function(){window.getSelection().selectAllChildren(b);b.focus()},0))});N(".gs_cith","click",function(a){(a=a.currentTarget.parentNode.querySelector(".gs_citr"))&&a.focus()});O(Z,be);
# E(function(){ce();Wd.add(de);for(var a={},b=document.querySelectorAll(".gs_or[data-did]"),c=b.length;c--;){var d=b[c],e=ae(d);d=d.getAttribute("data-lid")||"";a[e]=d}b=Y("data-lsl");try{var f=JSON.parse(b)}catch(h){}f&&da(f)&&!Za()||(f={});Xd(f);f=$d();b=Y("data-lpu");for(var g in a)c=a[g],e=f[g+","+b],e instanceof Array&&(e=""+e[0],c!=e&&(c=e,Wd.v({aa:g,ia:c,error:""})))});Dc.add(ce);ce();B(window,"pagehide",ce);
# N("#gs_res_sb_yyc","click",function(){w("gs_res_sb_yyf").style.display="block";for(var a=document.querySelectorAll("#gs_res_sb_yyl>li"),b=a.length;b--;)u(a[b],"gs_bdy_sb_sel",b==a.length-1)});N("#gs_scipsc","gs-change",function(a){var b=yc(a.currentTarget),c=va(w("gs_hdr_frm")),d=va(w("gs_asd_frm"));c.value=d.value=b?"1":"";a=a.currentTarget.getAttribute("data-msg")||"";w("gs_hdr_tsi").placeholder=b?a:""});Nb("#gs_res_drw_adv",function(){hd("gs_asd")});
# E(function(){var a=Y("data-ttl");a&&(document.title=a);a=new Ab("q");var b=Y("data-ahq");b&&a.add(b);Y("data-gsb")&&Ud()});O(ge,pe);B(window,"pagehide",function(){le();if(ee&&!je(ee)){var a={d:ee,u:he(),t:Date.now()};5E3<=Date.now()-fe&&(a={});var b=oe();ne()&&window.scrollTo(0,b);a.s=b;yb("rfr",a)}});
# B(window,"pageshow",function(){var a=ke(),b=he();if(a&&a.u==b)if(864E5<=Date.now()-(+a.t||0))yb("rfr",{});else{b=""+a.d;var c=Y("data-rfr");if(c&&!je(b)){var d=ne(),e=+a.s;e&&!d&&(v("Trident")||v("Edge"))&&Ga(window,"scroll",function(){window.scrollTo(0,e)},20);a.s=0;yb("rfr",a);var f=document.querySelector('.gs_or[data-did="'+b+'"]');if(f)if(d=a.h)me(f,""+d,!1);else{b=c.replace("{id}",b);var g=mb(b,"",function(b,c){200==b&&c&&(me(f,c,!0),a.h=c,a.t=Date.now(),yb("rfr",a));clearTimeout(h)}),h=setTimeout(function(){nb(g)},
# 500)}}}});
# }({"bouncePrefix":"http://scholar.google.se","neverBounce":!1,"customAC":0,"eventId":"-hC2XLq0J8qByQTM8bKwAQ"});
#   </script>
#  </head>
#  <body>
#   <div id="gs_top" onclick="">
#    <style>
#     #gs_md_s,.gs_md_wnw{z-index:1200;position:fixed;top:0;left:0;width:100%;height:100%;visibility:hidden;}#gs_md_s{background-color:#fff;opacity:.5;}.gs_el_ta #gs_md_s,.gs_el_ph #gs_md_s{background-color:#666;}.gs_md_wnw{transition:all 0s .218s;}#gs_md_s.gs_vis,.gs_md_wnw.gs_vis{visibility:visible;transition:all 0s;}.gs_md_wnw>.gs_md_d{position:relative;margin:0 auto;width:464px;box-shadow:2px 2px 8px rgba(0,0,0,.2);white-space:normal;}.gs_el_ta .gs_md_wnw>.gs_md_d,.gs_el_ph .gs_md_wnw>.gs_md_d{box-shadow:2px 2px 8px rgba(0,0,0,.65);}.gs_el_ph .gs_md_wnw>.gs_md_d{width:80%;max-width:440px;}.gs_el_ph .gs_md_wmw>.gs_md_d{width:100%;height:100%;max-width:none;border:none;box-shadow:none;transform:translate(0,100%);transform:translate(0,100vh);transition:transform .27s cubic-bezier(.4,0,.6,1),opacity 0s .27s,visibility 0s .27s,max-height 0s .27s;}.gs_el_ph .gs_md_wmw>.gs_md_d.gs_vis{transform:translate(0,0);transition:transform .3s cubic-bezier(0,0,.2,1);}.gs_md_wmw>.gs_md_d.gs_abt,.gs_el_ph .gs_md_wmw>.gs_md_d.gs_abt{transition:none;}.gs_md_hdr{display:flex;align-items:center;height:47px;border-bottom:1px solid #e0e0e0;border-bottom-color:rgba(0,0,0,.12);background-color:#f5f5f5;}.gs_md_hdr>a,.gs_md_hdr>a.gs_btn_lrge{flex:0 0 auto;width:41px;height:47px;}.gs_el_ph .gs_md_hdr>a{margin:0 2px 0 0;}.gs_el_ph a.gs_md_hdr_c{margin:0 0 0 2px;}.gs_md_hdr_b{margin:0 41px 0 16px;}.gs_el_ph .gs_md_hdr_b{margin:0 16px;}.gs_md_hdr_t:empty~.gs_md_hdr_b{margin-left:0;}.gs_md_hdr_b:empty{width:41px;margin:0;}.gs_el_ph .gs_md_hdr_b:empty{margin-right:2px;}.gs_md_hdr_b:empty:not(:last-child){display:none;}.gs_md_hdr_b>button{min-width:51px;height:33px;}.gs_md_hdr_t{flex:1 1 auto;font-size:18px;font-weight:normal;color:#666;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;text-align:center;}.gs_md_bdy{overflow-y:auto;box-sizing:border-box;padding:24px 41px 0 41px;}.gs_md_bdy:after{display:block;content:"";clear:both;padding-bottom:24px;}.gs_el_ph .gs_md_bdy{padding:16px 16px 0 16px;}.gs_el_ph .gs_md_bdy:after{padding-bottom:16px;}.gs_el_ph .gs_md_wmw .gs_md_bdy{position:absolute;width:100%;top:48px;bottom:0;}.gs_md_lbl{display:block;font-size:16px;margin:0 0 16px 0;word-wrap:break-word;}.gs_md_btns{margin:24px 0 0 0;white-space:nowrap;}.gs_el_ph .gs_md_btns{margin:16px 0 0 0;}.gs_md_btns button{margin-right:16px;}.gs_md_btns button:last-child{margin-right:0;}.gs_md_prg{margin:24px 0;text-align:center;}.gs_md_prg .gs_alrt{padding:4px 16px;}.gs_md_ldg:before{content:"";position:absolute;top:0;left:0;bottom:0;right:0;background-color:#fff;opacity:.5;z-index:100;}
#    </style>
#    <div id="gs_md_ldg" style="display:none">
#     Loading...
#    </div>
#    <div id="gs_md_err" style="display:none">
#     The system can't perform the operation now. Try again later.
#    </div>
#    <div id="gs_md_s">
#    </div>
#    <div class="gs_md_wnw gs_md_wmw" data-h="0">
# ...
#            G Gabadadze
#           </a>
#           ,
#           <a href="/citations?user=LEcbAYIAAAAJ&amp;hl=en&amp;oe=ASCII&amp;oi=sra">
#            M Porrati
#           </a>
#           - Physics Letters B, 2000 - Elsevier
#          </div>
#          <div class="gs_rs">
#           We suggest a mechanism by which four-dimensional Newtonian
#           <b>
#            gravity
#           </b>
#           emerges on a 3-
#           <br/>
#           brane in 5D Minkowski space with an infinite size extra dimension. The worldvolume theory
#           <br/>
#           gives rise to the correct 4D potential at short distances whereas at large distances the …
#          </div>
#          <div class="gs_fl">
#           <a class="gs_or_sav" href="javascript:void(0)" role="button" title="Save">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M8 11.57l3.824 2.308-1.015-4.35 3.379-2.926-4.45-.378L8 2.122 6.261 6.224l-4.449.378 3.379 2.926-1.015 4.35z">
#             </path>
#            </svg>
#           </a>
#           <a aria-controls="gs_cit" aria-haspopup="true" class="gs_or_cit gs_nph" href="javascript:void(0)" role="button" title="Cite">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 3.5v5h2v.375L1.75 12.5h3L6.5 8.875V3.5zM9.5 3.5v5h2v.375L9.75 12.5h3L14.5 8.875V3.5z">
#             </path>
#            </svg>
#           </a>
#           <a href="/scholar?cites=16695868001575310669&amp;as_sdt=2005&amp;sciodt=0,5&amp;hl=en&amp;oe=ASCII">
#            Cited by 3397
#           </a>
#           <a href="/scholar?q=related:TRW1Kn2js-cJ:scholar.google.com/&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            Related articles
#           </a>
#           <a class="gs_nph" href="/scholar?cluster=16695868001575310669&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            All 17 versions
#           </a>
#           <a class="gs_or_mor gs_oph" href="javascript:void(0)" role="button" title="More">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 5.5l2-2L8 8l-4.5 4.5-2-2L4 8zM8.5 5.5l2-2L15 8l-4.5 4.5-2-2L11 8z">
#             </path>
#            </svg>
#           </a>
#           <a class="gs_or_nvi gs_or_mor" href="javascript:void(0)" role="button" title="Fewer">
#            <svg class="gs_or_svg" viewbox="0 0 17 16">
#             <path d="M8.5 5.5l-2-2L2 8l4.5 4.5 2-2L6 8zM15.5 5.5l-2-2L9 8l4.5 4.5 2-2L13 8z">
#             </path>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="gs_r gs_or gs_scl" data-cid="eNHduAJb06wJ" data-did="eNHduAJb06wJ" data-lid="" data-rp="8">
#         <div class="gs_ggs gs_fl">
#          <div class="gs_ggsd">
#           <div class="gs_or_ggsm" ontouchstart="gs_evt_dsp(event)" tabindex="-1">
#            <a data-clk="hl=en&amp;sa=T&amp;oi=gga&amp;ct=gga&amp;cd=8&amp;d=12453397461859160440&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm3PFBmXJocS8xrkDZ_oARrGeUM-5A&amp;nossl=1" data-clk-atid="eNHduAJb06wJ" href="http://blogs.umass.edu/grqft/files/2014/11/DeWitt-Quantum-gravity-1.pdf">
#             <span class="gs_ctg2">
#              [PDF]
#             </span>
#             umass.edu
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="gs_ri">
#          <h3 class="gs_rt" ontouchstart="gs_evt_dsp(event)">
#           <a data-clk="hl=en&amp;sa=T&amp;ct=res&amp;cd=8&amp;d=12453397461859160440&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm3TYRhBmQiAuV81PYLFtqKqE3_D8Q&amp;nossl=1" data-clk-atid="eNHduAJb06wJ" href="https://journals.aps.org/pr/abstract/10.1103/PhysRev.160.1113" id="eNHduAJb06wJ">
#            Quantum theory of
#            <b>
#             gravity
#            </b>
#            . I. The canonical theory
#           </a>
#          </h3>
#          <div class="gs_a">
#           BS DeWitt - Physical Review, 1967 - APS
#          </div>
#          <div class="gs_rs">
#           Following an historical introduction, the conventional canonical formulation of general
#           <br/>
#           relativity theory is presented. The canonical Lagrangian is expressed in terms of the extrinsic
#           <br/>
#           and intrinsic curvatures of the hypersurface x 0= constant, and its relation to the asymptotic …
#          </div>
#          <div class="gs_fl">
#           <a class="gs_or_sav" href="javascript:void(0)" role="button" title="Save">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M8 11.57l3.824 2.308-1.015-4.35 3.379-2.926-4.45-.378L8 2.122 6.261 6.224l-4.449.378 3.379 2.926-1.015 4.35z">
#             </path>
#            </svg>
#           </a>
#           <a aria-controls="gs_cit" aria-haspopup="true" class="gs_or_cit gs_nph" href="javascript:void(0)" role="button" title="Cite">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 3.5v5h2v.375L1.75 12.5h3L6.5 8.875V3.5zM9.5 3.5v5h2v.375L9.75 12.5h3L14.5 8.875V3.5z">
#             </path>
#            </svg>
#           </a>
#           <a href="/scholar?cites=12453397461859160440&amp;as_sdt=2005&amp;sciodt=0,5&amp;hl=en&amp;oe=ASCII">
#            Cited by 3361
#           </a>
#           <a href="/scholar?q=related:eNHduAJb06wJ:scholar.google.com/&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            Related articles
#           </a>
#           <a class="gs_nph" href="/scholar?cluster=12453397461859160440&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            All 7 versions
#           </a>
#           <a class="gs_or_mor" href="javascript:void(0)" role="button" title="More">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 5.5l2-2L8 8l-4.5 4.5-2-2L4 8zM8.5 5.5l2-2L15 8l-4.5 4.5-2-2L11 8z">
#             </path>
#            </svg>
#           </a>
#           <a class="gs_or_nvi" href="http://scholar.google.se/scholar?output=instlink&amp;nossl=1&amp;q=info:eNHduAJb06wJ:scholar.google.com/&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5&amp;scillfp=12964704689886198227&amp;oi=llo">
#            Library Search
#           </a>
#           <a class="gs_or_nvi gs_or_mor" href="javascript:void(0)" role="button" title="Fewer">
#            <svg class="gs_or_svg" viewbox="0 0 17 16">
#             <path d="M8.5 5.5l-2-2L2 8l4.5 4.5 2-2L6 8zM15.5 5.5l-2-2L9 8l4.5 4.5 2-2L13 8z">
#             </path>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="gs_r gs_or gs_scl" data-cid="BlL2PfHFprwJ" data-did="BlL2PfHFprwJ" data-lid="" data-rp="9">
#         <div class="gs_ggs gs_fl">
#          <div class="gs_ggsd">
#           <div class="gs_or_ggsm" ontouchstart="gs_evt_dsp(event)" tabindex="-1">
#            <a data-clk="hl=en&amp;sa=T&amp;oi=gga&amp;ct=gga&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm21I0Ij_FEgtZZKBWQUwknwc1IgOA&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://arxiv.org/pdf/1011.1232">
#             <span class="gs_ctg2">
#              [PDF]
#             </span>
#             arxiv.org
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="gs_ri">
#          <h3 class="gs_rt" ontouchstart="gs_evt_dsp(event)">
#           <a data-clk="hl=en&amp;sa=T&amp;ct=res&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm0jsj4xQjXVn4jWuNhmDryZ8rJ8GQ&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.106.231101" id="BlL2PfHFprwJ">
#            Resummation of massive
#            <b>
#             gravity
#            </b>
#           </a>
#          </h3>
#          <div class="gs_a">
#           C De Rham,
#           <a href="/citations?user=XuY4eFQAAAAJ&amp;hl=en&amp;oe=ASCII&amp;oi=sra">
#            G Gabadadze
#           </a>
#           , AJ Tolley - Physical Review Letters, 2011 - APS
#          </div>
#          <div class="gs_rs">
#           We construct four-dimensional covariant nonlinear theories of massive
#           <b>
#            gravity
#           </b>
#           which are
#           <br/>
#           ghost-free in the decoupling limit to all orders. These theories resum explicitly all the
#           <br/>
#           nonlinear terms of an effective field theory of massive
#           <b>
#            gravity
#           </b>
#           . We show that away from the …
#          </div>
#          <div class="gs_fl">
#           <a class="gs_or_sav" href="javascript:void(0)" role="button" title="Save">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M8 11.57l3.824 2.308-1.015-4.35 3.379-2.926-4.45-.378L8 2.122 6.261 6.224l-4.449.378 3.379 2.926-1.015 4.35z">
#             </path>
#            </svg>
#           </a>
#           <a aria-controls="gs_cit" aria-haspopup="true" class="gs_or_cit gs_nph" href="javascript:void(0)" role="button" title="Cite">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 3.5v5h2v.375L1.75 12.5h3L6.5 8.875V3.5zM9.5 3.5v5h2v.375L9.75 12.5h3L14.5 8.875V3.5z">
#             </path>
#            </svg>
#           </a>
#           <a href="/scholar?cites=13593770165181764102&amp;as_sdt=2005&amp;sciodt=0,5&amp;hl=en&amp;oe=ASCII">
#            Cited by 1283
#           </a>
#           <a href="/scholar?q=related:BlL2PfHFprwJ:scholar.google.com/&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            Related articles
#           </a>
#           <a class="gs_nph" href="/scholar?cluster=13593770165181764102&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#            All 18 versions
#           </a>
#           <a class="gs_or_mor gs_oph" href="javascript:void(0)" role="button" title="More">
#            <svg class="gs_or_svg" viewbox="-1 0 17 16">
#             <path d="M1.5 5.5l2-2L8 8l-4.5 4.5-2-2L4 8zM8.5 5.5l2-2L15 8l-4.5 4.5-2-2L11 8z">
#             </path>
#            </svg>
#           </a>
#           <a class="gs_or_nvi gs_or_mor" href="javascript:void(0)" role="button" title="Fewer">
#            <svg class="gs_or_svg" viewbox="0 0 17 16">
#             <path d="M8.5 5.5l-2-2L2 8l4.5 4.5 2-2L6 8zM15.5 5.5l-2-2L9 8l4.5 4.5 2-2L13 8z">
#             </path>
#            </svg>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="gs_res_ccl_bot">
#        <div class="gs_r gs_alrt_btm gs_oph gs_ota">
#         <a class="gs_btnM gs_in_ib" href="/scholar_alerts?view_op=create_alert_options&amp;hl=en&amp;alert_query=intitle:gravity&amp;alert_params=%3Fhl%3Den%26as_sdt%3D0,5">
#          <span class="gs_ico">
#          </span>
#          <span class="gs_lbl">
#           Create alert
#          </span>
#         </a>
#        </div>
#        <div id="gs_n" role="navigation">
#         <center>
#          <table cellpadding="0" width="1%">
#           <tr align="center" valign="top">
#            <td align="right" nowrap="">
#             <span class="gs_ico gs_ico_nav_first">
#             </span>
#             <b style="display:block;margin-right:35px;visibility:hidden">
#              Previous
#             </b>
#            </td>
#            <td>
#             <span class="gs_ico gs_ico_nav_current">
#             </span>
#             <b>
#              1
#             </b>
#            </td>
#            <td>
#             <a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              2
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              3
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              4
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              5
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              6
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              7
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              8
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              9
#             </a>
#            </td>
#            <td>
#             <a href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_page">
#              </span>
#              10
#             </a>
#            </td>
#            <td align="left" nowrap="">
#             <a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#              <span class="gs_ico gs_ico_nav_next">
#              </span>
#              <b style="display:block;margin-left:53px">
#               Next
#              </b>
#             </a>
#            </td>
#           </tr>
#          </table>
#         </center>
#        </div>
#        <div id="gs_nm" role="navigation">
#         <button aria-label="Previous" class="gs_btnPL gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" disabled="" type="button">
#          <span class="gs_wr">
#           <span class="gs_ico">
#           </span>
#           <span class="gs_lbl">
#           </span>
#          </span>
#         </button>
#         <button aria-label="Next" class="gs_btnPR gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" onclick="window.location='/scholar?start\x3d10\x26q\x3dgravity\x26hl\x3den\x26oe\x3dASCII\x26as_sdt\x3d0,5'" type="button">
#          <span class="gs_wr">
#           <span class="gs_ico">
#           </span>
#           <span class="gs_lbl">
#           </span>
#          </span>
#         </button>
#         <div id="gs_nml">
#          <b class="gs_nma">
#           1
#          </b>
#          <a class="gs_nma" href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           2
#          </a>
#          <a class="gs_nma" href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           3
#          </a>
#          <a class="gs_nma" href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           4
#          </a>
#          <a class="gs_nma" href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           5
#          </a>
#          <a class="gs_nma" href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           6
#          </a>
#          <a class="gs_nma" href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           7
#          </a>
#          <a class="gs_nma" href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           8
#          </a>
#          <a class="gs_nma" href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           9
#          </a>
#          <a class="gs_nma" href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">
#           10
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <iframe src="//scholar.google.com/gen_nid" style="display:none">
#      </iframe>
#     </div>
#    </div>
#    <div id="gs_ftr_sp" role="presentation">
#    </div>
#    <div id="gs_ftr" role="contentinfo">
#     <div id="gs_ftr_rt">
#      <a href="/intl/en/scholar/about.html">
#       Help
#      </a>
#      <a href="//www.google.se/intl/en/policies/privacy/">
#       Privacy
#      </a>
#      <a href="//www.google.se/intl/en/policies/terms/">
#       Terms
#      </a>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
text.find_all('div')
# Out:
# [<div id="gs_top" onclick=""><style>#gs_md_s,.gs_md_wnw{z-index:1200;position:fixed;top:0;left:0;width:100%;height:100%;visibility:hidden;}#gs_md_s{background-color:#fff;opacity:.5;}.gs_el_ta #gs_md_s,.gs_el_ph #gs_md_s{background-color:#666;}.gs_md_wnw{transition:all 0s .218s;}#gs_md_s.gs_vis,.gs_md_wnw.gs_vis{visibility:visible;transition:all 0s;}.gs_md_wnw>.gs_md_d{position:relative;margin:0 auto;width:464px;box-shadow:2px 2px 8px rgba(0,0,0,.2);white-space:normal;}.gs_el_ta .gs_md_wnw>.gs_md_d,.gs_el_ph .gs_md_wnw>.gs_md_d{box-shadow:2px 2px 8px rgba(0,0,0,.65);}.gs_el_ph .gs_md_wnw>.gs_md_d{width:80%;max-width:440px;}.gs_el_ph .gs_md_wmw>.gs_md_d{width:100%;height:100%;max-width:none;border:none;box-shadow:none;transform:translate(0,100%);transform:translate(0,100vh);transition:transform .27s cubic-bezier(.4,0,.6,1),opacity 0s .27s,visibility 0s .27s,max-height 0s .27s;}.gs_el_ph .gs_md_wmw>.gs_md_d.gs_vis{transform:translate(0,0);transition:transform .3s cubic-bezier(0,0,.2,1);}.gs_md_wmw>.gs_md_d.gs_abt,.gs_el_ph .gs_md_wmw>.gs_md_d.gs_abt{transition:none;}.gs_md_hdr{display:flex;align-items:center;height:47px;border-bottom:1px solid #e0e0e0;border-bottom-color:rgba(0,0,0,.12);background-color:#f5f5f5;}.gs_md_hdr>a,.gs_md_hdr>a.gs_btn_lrge{flex:0 0 auto;width:41px;height:47px;}.gs_el_ph .gs_md_hdr>a{margin:0 2px 0 0;}.gs_el_ph a.gs_md_hdr_c{margin:0 0 0 2px;}.gs_md_hdr_b{margin:0 41px 0 16px;}.gs_el_ph .gs_md_hdr_b{margin:0 16px;}.gs_md_hdr_t:empty~.gs_md_hdr_b{margin-left:0;}.gs_md_hdr_b:empty{width:41px;margin:0;}.gs_el_ph .gs_md_hdr_b:empty{margin-right:2px;}.gs_md_hdr_b:empty:not(:last-child){display:none;}.gs_md_hdr_b>button{min-width:51px;height:33px;}.gs_md_hdr_t{flex:1 1 auto;font-size:18px;font-weight:normal;color:#666;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;text-align:center;}.gs_md_bdy{overflow-y:auto;box-sizing:border-box;padding:24px 41px 0 41px;}.gs_md_bdy:after{display:block;content:"";clear:both;padding-bottom:24px;}.gs_el_ph .gs_md_bdy{padding:16px 16px 0 16px;}.gs_el_ph .gs_md_bdy:after{padding-bottom:16px;}.gs_el_ph .gs_md_wmw .gs_md_bdy{position:absolute;width:100%;top:48px;bottom:0;}.gs_md_lbl{display:block;font-size:16px;margin:0 0 16px 0;word-wrap:break-word;}.gs_md_btns{margin:24px 0 0 0;white-space:nowrap;}.gs_el_ph .gs_md_btns{margin:16px 0 0 0;}.gs_md_btns button{margin-right:16px;}.gs_md_btns button:last-child{margin-right:0;}.gs_md_prg{margin:24px 0;text-align:center;}.gs_md_prg .gs_alrt{padding:4px 16px;}.gs_md_ldg:before{content:"";position:absolute;top:0;left:0;bottom:0;right:0;background-color:#fff;opacity:.5;z-index:100;}</style><div id="gs_md_ldg" style="display:none">Loading...</div><div id="gs_md_err" style="display:none">The system can't perform the operation now. Try again later.</div><div id="gs_md_s"></div><div class="gs_md_wnw gs_md_wmw" data-h="0"><div aria-labelledby="gs_cit-t" class="gs_md_d gs_ttzi" data-cid="gs_citd" data-wfc="gs_cit-x" id="gs_cit" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_cit-t">Cite</h2><div class="gs_md_hdr_b"></div></div><div class="gs_md_bdy" id="gs_cit-bdy"><style>#gs_cit{width:520px;max-width:80%;}.gs_el_ph #gs_cit{width:100%;max-width:100%;}#gs_citt table{width:100%;margin-top:-8px;}#gs_citt td,#gs_citt th{vertical-align:top;padding:8px 0;}#gs_citt th{text-align:right;font-weight:normal;color:#777;padding-right:16px;white-space:nowrap;user-select:none;}#gs_citi{margin:16px 0 0 0;text-align:center;}.gs_el_ph #gs_citi{margin:16px 0 8px 0;}.gs_citi{margin-right:16px;white-space:nowrap;padding:7px 0 5px 0;}.gs_citi:first-child{margin-left:16px;}</style><div aria-live="assertive" data-u="/scholar?q=info:{id}:scholar.google.com/&amp;output=cite&amp;scirp={p}&amp;hl=en" id="gs_citd"></div> ...
#  <div id="gs_md_ldg" style="display:none">Loading...</div>,
#  <div id="gs_md_err" style="display:none">The system can't perform the operation now. Try again later.</div>,
#  <div id="gs_md_s"></div>,
#  <div class="gs_md_wnw gs_md_wmw" data-h="0"><div aria-labelledby="gs_cit-t" class="gs_md_d gs_ttzi" data-cid="gs_citd" data-wfc="gs_cit-x" id="gs_cit" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_cit-t">Cite</h2><div class="gs_md_hdr_b"></div></div><div class="gs_md_bdy" id="gs_cit-bdy"><style>#gs_cit{width:520px;max-width:80%;}.gs_el_ph #gs_cit{width:100%;max-width:100%;}#gs_citt table{width:100%;margin-top:-8px;}#gs_citt td,#gs_citt th{vertical-align:top;padding:8px 0;}#gs_citt th{text-align:right;font-weight:normal;color:#777;padding-right:16px;white-space:nowrap;user-select:none;}#gs_citi{margin:16px 0 0 0;text-align:center;}.gs_el_ph #gs_citi{margin:16px 0 8px 0;}.gs_citi{margin-right:16px;white-space:nowrap;padding:7px 0 5px 0;}.gs_citi:first-child{margin-left:16px;}</style><div aria-live="assertive" data-u="/scholar?q=info:{id}:scholar.google.com/&amp;output=cite&amp;scirp={p}&amp;hl=en" id="gs_citd"></div></div></div></div>,
#  <div aria-labelledby="gs_cit-t" class="gs_md_d gs_ttzi" data-cid="gs_citd" data-wfc="gs_cit-x" id="gs_cit" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_cit-t">Cite</h2><div class="gs_md_hdr_b"></div></div><div class="gs_md_bdy" id="gs_cit-bdy"><style>#gs_cit{width:520px;max-width:80%;}.gs_el_ph #gs_cit{width:100%;max-width:100%;}#gs_citt table{width:100%;margin-top:-8px;}#gs_citt td,#gs_citt th{vertical-align:top;padding:8px 0;}#gs_citt th{text-align:right;font-weight:normal;color:#777;padding-right:16px;white-space:nowrap;user-select:none;}#gs_citi{margin:16px 0 0 0;text-align:center;}.gs_el_ph #gs_citi{margin:16px 0 8px 0;}.gs_citi{margin-right:16px;white-space:nowrap;padding:7px 0 5px 0;}.gs_citi:first-child{margin-left:16px;}</style><div aria-live="assertive" data-u="/scholar?q=info:{id}:scholar.google.com/&amp;output=cite&amp;scirp={p}&amp;hl=en" id="gs_citd"></div></div></div>,
#  <div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_cit-t">Cite</h2><div class="gs_md_hdr_b"></div></div>,
#  <div class="gs_md_hdr_b"></div>,
#  <div class="gs_md_bdy" id="gs_cit-bdy"><style>#gs_cit{width:520px;max-width:80%;}.gs_el_ph #gs_cit{width:100%;max-width:100%;}#gs_citt table{width:100%;margin-top:-8px;}#gs_citt td,#gs_citt th{vertical-align:top;padding:8px 0;}#gs_citt th{text-align:right;font-weight:normal;color:#777;padding-right:16px;white-space:nowrap;user-select:none;}#gs_citi{margin:16px 0 0 0;text-align:center;}.gs_el_ph #gs_citi{margin:16px 0 8px 0;}.gs_citi{margin-right:16px;white-space:nowrap;padding:7px 0 5px 0;}.gs_citi:first-child{margin-left:16px;}</style><div aria-live="assertive" data-u="/scholar?q=info:{id}:scholar.google.com/&amp;output=cite&amp;scirp={p}&amp;hl=en" id="gs_citd"></div></div>,
#  <div aria-live="assertive" data-u="/scholar?q=info:{id}:scholar.google.com/&amp;output=cite&amp;scirp={p}&amp;hl=en" id="gs_citd"></div>,
#  <div class="gs_md_wnw gs_md_wmw" data-h="0"><div aria-labelledby="gs_asd-t" class="gs_md_d gs_ttzi" data-ifc="gs_asd_q" data-wfc="gs_asd-x" id="gs_asd" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_asd" href="javascript:void(0)" id="gs_asd-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_asd-t">Advanced search</h2><div class="gs_md_hdr_b"><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_asd_psb" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></div></div><div class="gs_md_bdy" id="gs_asd-bdy"><style>#gs_asd{width:80%;max-width:552px;}.gs_el_ph #gs_asd{width:100%;max-width:100%;}#gs_asd_frm{margin-top:-6px;}.gs_el_tc #gs_asd_frm{margin-top:-8px;}.gs_asd_tr{clear:both;}.gs_el_tc .gs_asd_tr{padding:8px 0;}.gs_el_tc .gs_asd_tr:first-child{padding-bottom:0;}.gs_asd_dt{float:left;width:190px;padding:6px 2px 2px;}.gs_el_tc .gs_asd_dt{float:none;width:auto;padding:0 0 4px 0;}.gs_asd_dd{margin-left:194px;padding:2px;}.gs_el_tc .gs_asd_dd{margin-left:0;padding:0;}.gs_asd_yri .gs_in_txt{width:48px;}.gs_el_ph #gs_asd input,.gs_el_ph #gs_asd label{-webkit-tap-highlight-color:rgba(0,0,0,0);}.gs_asd_occtr{padding:5px 0;}.gs_el_tc .gs_asd_occtr{padding:0;}</style><form action="/scholar" class="gs_scl" id="gs_asd_frm"><div class="gs_asd_tr"><div class="gs_asd_dt" id="gs_asd_dt_t"><b>Find articles</b></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_q">with <b>all</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_epq">with the <b>exact phrase</b></label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_oq">with <b>at least one</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_eq"><b>without</b> the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_occt">where my words occur</label></div><div class="gs_asd_dd"><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_sau">Return articles <b>authored</b> by</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div><div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_pub">Return articles <b>published</b> in</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><inpu ...
#  <div aria-labelledby="gs_asd-t" class="gs_md_d gs_ttzi" data-ifc="gs_asd_q" data-wfc="gs_asd-x" id="gs_asd" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_asd" href="javascript:void(0)" id="gs_asd-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_asd-t">Advanced search</h2><div class="gs_md_hdr_b"><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_asd_psb" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></div></div><div class="gs_md_bdy" id="gs_asd-bdy"><style>#gs_asd{width:80%;max-width:552px;}.gs_el_ph #gs_asd{width:100%;max-width:100%;}#gs_asd_frm{margin-top:-6px;}.gs_el_tc #gs_asd_frm{margin-top:-8px;}.gs_asd_tr{clear:both;}.gs_el_tc .gs_asd_tr{padding:8px 0;}.gs_el_tc .gs_asd_tr:first-child{padding-bottom:0;}.gs_asd_dt{float:left;width:190px;padding:6px 2px 2px;}.gs_el_tc .gs_asd_dt{float:none;width:auto;padding:0 0 4px 0;}.gs_asd_dd{margin-left:194px;padding:2px;}.gs_el_tc .gs_asd_dd{margin-left:0;padding:0;}.gs_asd_yri .gs_in_txt{width:48px;}.gs_el_ph #gs_asd input,.gs_el_ph #gs_asd label{-webkit-tap-highlight-color:rgba(0,0,0,0);}.gs_asd_occtr{padding:5px 0;}.gs_el_tc .gs_asd_occtr{padding:0;}</style><form action="/scholar" class="gs_scl" id="gs_asd_frm"><div class="gs_asd_tr"><div class="gs_asd_dt" id="gs_asd_dt_t"><b>Find articles</b></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_q">with <b>all</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_epq">with the <b>exact phrase</b></label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_oq">with <b>at least one</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_eq"><b>without</b> the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_occt">where my words occur</label></div><div class="gs_asd_dd"><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_sau">Return articles <b>authored</b> by</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div><div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_pub">Return articles <b>published</b> in</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id= ...
#  <div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_asd" href="javascript:void(0)" id="gs_asd-x" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_asd-t">Advanced search</h2><div class="gs_md_hdr_b"><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_asd_psb" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></div></div>,
#  <div class="gs_md_hdr_b"><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_asd_psb" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></div>,
#  <div class="gs_md_bdy" id="gs_asd-bdy"><style>#gs_asd{width:80%;max-width:552px;}.gs_el_ph #gs_asd{width:100%;max-width:100%;}#gs_asd_frm{margin-top:-6px;}.gs_el_tc #gs_asd_frm{margin-top:-8px;}.gs_asd_tr{clear:both;}.gs_el_tc .gs_asd_tr{padding:8px 0;}.gs_el_tc .gs_asd_tr:first-child{padding-bottom:0;}.gs_asd_dt{float:left;width:190px;padding:6px 2px 2px;}.gs_el_tc .gs_asd_dt{float:none;width:auto;padding:0 0 4px 0;}.gs_asd_dd{margin-left:194px;padding:2px;}.gs_el_tc .gs_asd_dd{margin-left:0;padding:0;}.gs_asd_yri .gs_in_txt{width:48px;}.gs_el_ph #gs_asd input,.gs_el_ph #gs_asd label{-webkit-tap-highlight-color:rgba(0,0,0,0);}.gs_asd_occtr{padding:5px 0;}.gs_el_tc .gs_asd_occtr{padding:0;}</style><form action="/scholar" class="gs_scl" id="gs_asd_frm"><div class="gs_asd_tr"><div class="gs_asd_dt" id="gs_asd_dt_t"><b>Find articles</b></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_q">with <b>all</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_epq">with the <b>exact phrase</b></label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_oq">with <b>at least one</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_eq"><b>without</b> the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_occt">where my words occur</label></div><div class="gs_asd_dd"><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_sau">Return articles <b>authored</b> by</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div><div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_pub">Return articles <b>published</b> in</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_pub" name="as_publication" type="text" value=""/></div><div>e.g., <i>J Biol Chem</i> or <i>Nature</i></div></div></div><div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_ylo">Return articles <b>dated</b> between</label></div><div class="gs_asd_dd"><div class="gs_asd_yri"><div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_ylo" maxlength="4" name="as_ylo" pattern="[0-9]*" size="4" type="text" value=""/></div> — <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_yhi" maxlength="4" name="as_yhi" pattern="[0-9]*" size="4" type="text" value=""/></div></div><div>e.g., <i>19 ...
#  <div class="gs_asd_tr"><div class="gs_asd_dt" id="gs_asd_dt_t"><b>Find articles</b></div></div>,
#  <div class="gs_asd_dt" id="gs_asd_dt_t"><b>Find articles</b></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_q">with <b>all</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_q">with <b>all</b> of the words</label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_q" name="as_q" type="text" value="gravity"/></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_epq">with the <b>exact phrase</b></label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_epq">with the <b>exact phrase</b></label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_epq" name="as_epq" type="text" value=""/></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_oq">with <b>at least one</b> of the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_oq">with <b>at least one</b> of the words</label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_oq" name="as_oq" type="text" value=""/></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_eq"><b>without</b> the words</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_eq"><b>without</b> the words</label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_eq" name="as_eq" type="text" value=""/></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_occt">where my words occur</label></div><div class="gs_asd_dd"><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_occt">where my words occur</label></div>,
#  <div class="gs_asd_dd"><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div><div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div></div>,
#  <div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input checked="" id="gs_asd_occt_a" name="as_occt" type="radio" value="any"/><label for="gs_asd_occt_a">anywhere in the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div>,
#  <div class="gs_asd_occtr"><span class="gs_in_ra" onclick="void(0)"><input id="gs_asd_occt_t" name="as_occt" type="radio" value="title"/><label for="gs_asd_occt_t">in the title of the article</label><span class="gs_chk"></span><span class="gs_cbx"></span></span></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_sau">Return articles <b>authored</b> by</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div><div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_sau">Return articles <b>authored</b> by</label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div><div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_sau" name="as_sauthors" type="text" value=""/></div>,
#  <div>e.g., <i>"PJ Hayes"</i> or <i>McCarthy</i></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_pub">Return articles <b>published</b> in</label></div><div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_pub" name="as_publication" type="text" value=""/></div><div>e.g., <i>J Biol Chem</i> or <i>Nature</i></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_pub">Return articles <b>published</b> in</label></div>,
#  <div class="gs_asd_dd"><div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_pub" name="as_publication" type="text" value=""/></div><div>e.g., <i>J Biol Chem</i> or <i>Nature</i></div></div>,
#  <div class="gs_in_txtw gs_in_txtm gs_in_txtb"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_pub" name="as_publication" type="text" value=""/></div>,
#  <div>e.g., <i>J Biol Chem</i> or <i>Nature</i></div>,
#  <div class="gs_asd_tr"><div class="gs_asd_dt"><label for="gs_asd_ylo">Return articles <b>dated</b> between</label></div><div class="gs_asd_dd"><div class="gs_asd_yri"><div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_ylo" maxlength="4" name="as_ylo" pattern="[0-9]*" size="4" type="text" value=""/></div> — <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_yhi" maxlength="4" name="as_yhi" pattern="[0-9]*" size="4" type="text" value=""/></div></div><div>e.g., <i>1996</i></div></div></div>,
#  <div class="gs_asd_dt"><label for="gs_asd_ylo">Return articles <b>dated</b> between</label></div>,
#  <div class="gs_asd_dd"><div class="gs_asd_yri"><div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_ylo" maxlength="4" name="as_ylo" pattern="[0-9]*" size="4" type="text" value=""/></div> — <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_yhi" maxlength="4" name="as_yhi" pattern="[0-9]*" size="4" type="text" value=""/></div></div><div>e.g., <i>1996</i></div></div>,
#  <div class="gs_asd_yri"><div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_ylo" maxlength="4" name="as_ylo" pattern="[0-9]*" size="4" type="text" value=""/></div> — <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_yhi" maxlength="4" name="as_yhi" pattern="[0-9]*" size="4" type="text" value=""/></div></div>,
#  <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_ylo" maxlength="4" name="as_ylo" pattern="[0-9]*" size="4" type="text" value=""/></div>,
#  <div class="gs_in_txtw gs_in_txtm"><input autocapitalize="off" class="gs_in_txt" id="gs_asd_yhi" maxlength="4" name="as_yhi" pattern="[0-9]*" size="4" type="text" value=""/></div>,
#  <div>e.g., <i>1996</i></div>,
#  <div id="gs_hdr_drs"></div>,
#  <div class="gs_md_ulr" data-cfc="gs_hdr_mnu" data-shd="gs_hdr_drs" data-wfc="gs_hdr_drw_mnu" id="gs_hdr_drw" role="dialog" tabindex="-1"><div id="gs_hdr_drw_in"><div id="gs_hdr_drw_top"><a aria-controls="gs_hdr_drw" aria-label="Options" class="gs_btnMNT gs_in_ib gs_btn_lrge" href="javascript:void(0)" id="gs_hdr_drw_mnu" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><a aria-label="Homepage" href="/schhp?hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_lgo"></a><a aria-label="Settings" class="gs_btnP gs_in_ib gs_btn_lrge" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_set" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a></div><div><div class="gs_hdr_drw_sec"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray gs_sel" href="/scholar?as_sdt=0,5&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Articles</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?as_sdt=2006&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Case law</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=search_authors&amp;mauthors=gravity&amp;hl=en&amp;oe=ASCII&amp;oi=drw" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Profiles</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnPRO gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My profile</span></a><a class="gs_btnL gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?scilib=1&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My library</span></a><a class="gs_btnM gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_alerts?view_op=list_alerts&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Alerts</span></a><a class="gs_btnJ gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=top_venues&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Metrics</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnADV gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="javascript:void(0)" id="gs_res_drw_adv" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Advanced search</span></a></div><div class="gs_hdr_drw_sec" id="gs_hdr_drw_bs"><a class="gs_btnP gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Settings</span></a></div></div><div class="gs_hdr_drw_sec" id="gs_hdr_drw_bot"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="https://accounts.google.com/Login?hl=en&amp;continue=https://scholar.google.se/scholar%3Fhl%3Den%26q%3Dgravity"><span class="gs_ico"></span><span class="gs_lbl">Sign in</span></a></div></div></div>,
#  <div id="gs_hdr_drw_in"><div id="gs_hdr_drw_top"><a aria-controls="gs_hdr_drw" aria-label="Options" class="gs_btnMNT gs_in_ib gs_btn_lrge" href="javascript:void(0)" id="gs_hdr_drw_mnu" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><a aria-label="Homepage" href="/schhp?hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_lgo"></a><a aria-label="Settings" class="gs_btnP gs_in_ib gs_btn_lrge" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_set" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a></div><div><div class="gs_hdr_drw_sec"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray gs_sel" href="/scholar?as_sdt=0,5&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Articles</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?as_sdt=2006&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Case law</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=search_authors&amp;mauthors=gravity&amp;hl=en&amp;oe=ASCII&amp;oi=drw" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Profiles</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnPRO gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My profile</span></a><a class="gs_btnL gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?scilib=1&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My library</span></a><a class="gs_btnM gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_alerts?view_op=list_alerts&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Alerts</span></a><a class="gs_btnJ gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=top_venues&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Metrics</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnADV gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="javascript:void(0)" id="gs_res_drw_adv" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Advanced search</span></a></div><div class="gs_hdr_drw_sec" id="gs_hdr_drw_bs"><a class="gs_btnP gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Settings</span></a></div></div><div class="gs_hdr_drw_sec" id="gs_hdr_drw_bot"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="https://accounts.google.com/Login?hl=en&amp;continue=https://scholar.google.se/scholar%3Fhl%3Den%26q%3Dgravity"><span class="gs_ico"></span><span class="gs_lbl">Sign in</span></a></div></div>,
#  <div id="gs_hdr_drw_top"><a aria-controls="gs_hdr_drw" aria-label="Options" class="gs_btnMNT gs_in_ib gs_btn_lrge" href="javascript:void(0)" id="gs_hdr_drw_mnu" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><a aria-label="Homepage" href="/schhp?hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_lgo"></a><a aria-label="Settings" class="gs_btnP gs_in_ib gs_btn_lrge" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_drw_set" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a></div>,
#  <div><div class="gs_hdr_drw_sec"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray gs_sel" href="/scholar?as_sdt=0,5&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Articles</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?as_sdt=2006&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Case law</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=search_authors&amp;mauthors=gravity&amp;hl=en&amp;oe=ASCII&amp;oi=drw" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Profiles</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnPRO gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My profile</span></a><a class="gs_btnL gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?scilib=1&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My library</span></a><a class="gs_btnM gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_alerts?view_op=list_alerts&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Alerts</span></a><a class="gs_btnJ gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=top_venues&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Metrics</span></a></div><div class="gs_hdr_drw_sec"><a class="gs_btnADV gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="javascript:void(0)" id="gs_res_drw_adv" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Advanced search</span></a></div><div class="gs_hdr_drw_sec" id="gs_hdr_drw_bs"><a class="gs_btnP gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Settings</span></a></div></div>,
#  <div class="gs_hdr_drw_sec"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray gs_sel" href="/scholar?as_sdt=0,5&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Articles</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?as_sdt=2006&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Case law</span></a><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=search_authors&amp;mauthors=gravity&amp;hl=en&amp;oe=ASCII&amp;oi=drw" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Profiles</span></a></div>,
#  <div class="gs_hdr_drw_sec"><a class="gs_btnPRO gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My profile</span></a><a class="gs_btnL gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar?scilib=1&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">My library</span></a><a class="gs_btnM gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_alerts?view_op=list_alerts&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Alerts</span></a><a class="gs_btnJ gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/citations?view_op=top_venues&amp;hl=en&amp;oe=ASCII" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Metrics</span></a></div>,
#  <div class="gs_hdr_drw_sec"><a class="gs_btnADV gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="javascript:void(0)" id="gs_res_drw_adv" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Advanced search</span></a></div>,
#  <div class="gs_hdr_drw_sec" id="gs_hdr_drw_bs"><a class="gs_btnP gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="/scholar_settings?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitem"><span class="gs_ico"></span><span class="gs_lbl">Settings</span></a></div>,
#  <div class="gs_hdr_drw_sec" id="gs_hdr_drw_bot"><a class=" gs_in_ib gs_md_li gs_md_lix gs_in_gray" href="https://accounts.google.com/Login?hl=en&amp;continue=https://scholar.google.se/scholar%3Fhl%3Den%26q%3Dgravity"><span class="gs_ico"></span><span class="gs_lbl">Sign in</span></a></div>,
#  <div id="gs_hdr" role="banner"><a aria-controls="gs_hdr_drw" class="gs_btnMNT gs_in_ib gs_btn_lrge" href="javascript:void(0)" id="gs_hdr_mnu" role="button"><span class="gs_ico"></span><span class="gs_lbl"></span></a><a aria-label="Homepage" class="gs_hdr_dso" href="/schhp?hl=en&amp;oe=ASCII&amp;as_sdt=0,5" id="gs_hdr_lgo"></a><div id="gs_hdr_md"><div id="gs_hdr_srch"><form action="/scholar" class="gs_hdr_tsc" id="gs_hdr_frm"><input name="hl" type="hidden" value="en"/><input name="oe" type="hidden" value="ASCII"/><input name="as_sdt" type="hidden" value="0,5"/><div class="gs_in_txtw gs_in_txtb"><input aria-label="Search" autocapitalize="off" class="gs_in_txt" id="gs_hdr_tsi" maxlength="2048" name="q" size="50" type="text" value="gravity"/></div><span id="gs_hdr_tsc"><span class="gs_ico gs_ico_X"></span></span><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_hdr_tsb" name="btnG" type="submit"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></form></div></div><div id="gs_hdr_act"><a href="https://accounts.google.com/Login?hl=en&amp;continue=https://scholar.google.se/scholar%3Fhl%3Den%26q%3Dgravity" id="gs_hdr_act_s">Sign in</a></div></div>,
#  <div id="gs_hdr_md"><div id="gs_hdr_srch"><form action="/scholar" class="gs_hdr_tsc" id="gs_hdr_frm"><input name="hl" type="hidden" value="en"/><input name="oe" type="hidden" value="ASCII"/><input name="as_sdt" type="hidden" value="0,5"/><div class="gs_in_txtw gs_in_txtb"><input aria-label="Search" autocapitalize="off" class="gs_in_txt" id="gs_hdr_tsi" maxlength="2048" name="q" size="50" type="text" value="gravity"/></div><span id="gs_hdr_tsc"><span class="gs_ico gs_ico_X"></span></span><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_hdr_tsb" name="btnG" type="submit"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></form></div></div>,
#  <div id="gs_hdr_srch"><form action="/scholar" class="gs_hdr_tsc" id="gs_hdr_frm"><input name="hl" type="hidden" value="en"/><input name="oe" type="hidden" value="ASCII"/><input name="as_sdt" type="hidden" value="0,5"/><div class="gs_in_txtw gs_in_txtb"><input aria-label="Search" autocapitalize="off" class="gs_in_txt" id="gs_hdr_tsi" maxlength="2048" name="q" size="50" type="text" value="gravity"/></div><span id="gs_hdr_tsc"><span class="gs_ico gs_ico_X"></span></span><button aria-label="Search" class="gs_btnG gs_in_ib gs_btn_act gs_btn_half gs_btn_lsb" id="gs_hdr_tsb" name="btnG" type="submit"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button></form></div>,
#  <div class="gs_in_txtw gs_in_txtb"><input aria-label="Search" autocapitalize="off" class="gs_in_txt" id="gs_hdr_tsi" maxlength="2048" name="q" size="50" type="text" value="gravity"/></div>,
#  <div id="gs_hdr_act"><a href="https://accounts.google.com/Login?hl=en&amp;continue=https://scholar.google.se/scholar%3Fhl%3Den%26q%3Dgravity" id="gs_hdr_act_s">Sign in</a></div>,
#  <div class="" id="gs_alrt_w" role="alert"><div id="gs_alrt_p"><form><input id="gs_alrt_ss"/></form><form action="" class="gs_alrt" id="gs_alrt" method="post"><span id="gs_alrt_m"></span><span id="gs_alrt_h"></span><a href="javascript:void(0)" id="gs_alrt_l" onclick="document.getElementById('gs_alrt').submit()"></a></form></div></div>,
#  <div id="gs_alrt_p"><form><input id="gs_alrt_ss"/></form><form action="" class="gs_alrt" id="gs_alrt" method="post"><span id="gs_alrt_m"></span><span id="gs_alrt_h"></span><a href="javascript:void(0)" id="gs_alrt_l" onclick="document.getElementById('gs_alrt').submit()"></a></form></div>,
#  <div class=" gs_ab_st" id="gs_ab"><div class="gs_btnGSL" id="gs_ab_ico"><span class="gs_ico"></span></div><div id="gs_ab_ttl"><div class="gs_ab_mdw"><span class="gs_nph gs_nta">Articles</span><div class="gs_oph gs_ota">Scholar</div></div></div><div id="gs_ab_md"><div class="gs_ab_mdw">About 3,450,000 results (<b>0.03</b> sec)</div></div><div id="gs_ab_btns"><a class="gs_btnPRO gs_in_ib gs_nph gs_nta" href="/citations?hl=en&amp;oe=ASCII"><span class="gs_ico"></span><span class="gs_lbl">My profile</span></a><a class="gs_btnL gs_in_ib gs_nph gs_nta" href="/scholar?scilib=1&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico"></span><span class="gs_lbl">My library</span></a><div class="gs_md_r gs_md_rmb gs_md_rmbl" id="gs_res_ab_yy-r"><button aria-controls="gs_res_ab_yy-d" aria-haspopup="true" class=" gs_in_se gs_btn_mnu gs_btn_flat gs_btn_lrge gs_btn_half gs_btn_lsu gs_press gs_md_tb" id="gs_res_ab_yy-b" ontouchstart="gs_evt_dsp(event)" type="button"><span class="gs_wr"><span class="gs_lbl">Year</span><span class="gs_icm"></span></span></button><div class="gs_md_d gs_md_ulr" id="gs_res_ab_yy-d" role="menu" tabindex="-1"><div class="gs_res_ab_dd_bdy"><div class="gs_res_ab_dd_sec"><a aria-checked="true" class="gs_md_li gs_res_ab_sel" href="/scholar?q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitemradio" tabindex="-1">Any time</a><a class="gs_md_li" href="/scholar?as_ylo=2019&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitemradio" tabindex="-1">Since 2019</a><a class="gs_md_li" href="/scholar?as_ylo=2018&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitemradio" tabindex="-1">Since 2018</a><a class="gs_md_li" href="/scholar?as_ylo=2015&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitemradio" tabindex="-1">Since 2015</a></div><div class="gs_res_ab_dd_sec"><a aria-checked="true" class="gs_md_li gs_res_ab_sel" href="/scholar?hl=en&amp;oe=ASCII&amp;as_sdt=0,5&amp;q=gravity" role="menuitemradio" tabindex="-1">Sort by relevance</a><a class="gs_md_li" href="/scholar?hl=en&amp;oe=ASCII&amp;as_sdt=0,5&amp;q=gravity&amp;scisbd=1" role="menuitemradio" tabindex="-1">Sort by date</a></div></div></div></div><div class="gs_md_r gs_md_rmb gs_md_rmbl" id="gs_res_ab_ad-r"><button aria-controls="gs_res_ab_ad-d" aria-haspopup="true" aria-label="More" class="gs_btnFLT gs_in_ib gs_btn_flat gs_btn_lrge gs_btn_half gs_btn_lsu gs_press gs_md_tb" id="gs_res_ab_ad-b" ontouchstart="gs_evt_dsp(event)" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button><div class="gs_md_d gs_md_ulr" id="gs_res_ab_ad-d" role="menu" tabindex="-1"><div class="gs_res_ab_dd_bdy"><div class="gs_res_ab_dd_sec"><a aria-checked="true" class="gs_cb_gen gs_in_cb gs_md_li gs_sel" data-s="1" href="/scholar?as_sdt=1,5&amp;q=gravity&amp;hl=en&amp;oe=ASCII" role="menuitemcheckbox" tabindex="-1"><span class="gs_lbl">include patents</span><span class="gs_chk"></span><span class="gs_cbx"></span></a><a aria-checked="true" class="gs_cb_gen gs_in_cb gs_md_li gs_sel" data-s="1" href="/scholar?as_vis=1&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5" role="menuitemcheckbox" tabindex="-1"><span class="gs_lbl">include citations</span><span class="gs_chk"></span><span class="gs_cbx"></span></a></div></div></div></div></div></div>,
#  <div class="gs_btnGSL" id="gs_ab_ico"><span class="gs_ico"></span></div>,
#  <div id="gs_ab_ttl"><div class="gs_ab_mdw"><span class="gs_nph gs_nta">Articles</span><div class="gs_oph gs_ota">Scholar</div></div></div>,
#  <div class="gs_ab_mdw"><span class="gs_nph gs_nta">Articles</span><div class="gs_oph gs_ota">Scholar</div></div>,
#  <div class="gs_oph gs_ota">Scholar</div>,
#  <div id="gs_ab_md"><div class="gs_ab_mdw">About 3,450,000 results (<b>0.03</b> sec)</div></div>,
#  <div class="gs_ab_mdw">About 3,450,000 results (<b>0.03</b> sec)</div>,
# ...
#  <div class="gs_ggs gs_fl"><div class="gs_ggsd"><div class="gs_or_ggsm" ontouchstart="gs_evt_dsp(event)" tabindex="-1"><a data-clk="hl=en&amp;sa=T&amp;oi=gga&amp;ct=gga&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm21I0Ij_FEgtZZKBWQUwknwc1IgOA&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://arxiv.org/pdf/1011.1232"><span class="gs_ctg2">[PDF]</span> arxiv.org</a></div></div></div>,
#  <div class="gs_ggsd"><div class="gs_or_ggsm" ontouchstart="gs_evt_dsp(event)" tabindex="-1"><a data-clk="hl=en&amp;sa=T&amp;oi=gga&amp;ct=gga&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm21I0Ij_FEgtZZKBWQUwknwc1IgOA&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://arxiv.org/pdf/1011.1232"><span class="gs_ctg2">[PDF]</span> arxiv.org</a></div></div>,
#  <div class="gs_or_ggsm" ontouchstart="gs_evt_dsp(event)" tabindex="-1"><a data-clk="hl=en&amp;sa=T&amp;oi=gga&amp;ct=gga&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm21I0Ij_FEgtZZKBWQUwknwc1IgOA&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://arxiv.org/pdf/1011.1232"><span class="gs_ctg2">[PDF]</span> arxiv.org</a></div>,
#  <div class="gs_ri"><h3 class="gs_rt" ontouchstart="gs_evt_dsp(event)"><a data-clk="hl=en&amp;sa=T&amp;ct=res&amp;cd=9&amp;d=13593770165181764102&amp;ei=-hC2XLq0J8qByQTM8bKwAQ&amp;scisig=AAGBfm0jsj4xQjXVn4jWuNhmDryZ8rJ8GQ&amp;nossl=1" data-clk-atid="BlL2PfHFprwJ" href="https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.106.231101" id="BlL2PfHFprwJ">Resummation of massive <b>gravity</b></a></h3><div class="gs_a">C De Rham, <a href="/citations?user=XuY4eFQAAAAJ&amp;hl=en&amp;oe=ASCII&amp;oi=sra">G Gabadadze</a>, AJ Tolley - Physical Review Letters, 2011 - APS</div><div class="gs_rs">We construct four-dimensional covariant nonlinear theories of massive <b>gravity </b>which are <br/>ghost-free in the decoupling limit to all orders. These theories resum explicitly all the <br/>nonlinear terms of an effective field theory of massive <b>gravity</b>. We show that away from the …</div><div class="gs_fl"><a class="gs_or_sav" href="javascript:void(0)" role="button" title="Save"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M8 11.57l3.824 2.308-1.015-4.35 3.379-2.926-4.45-.378L8 2.122 6.261 6.224l-4.449.378 3.379 2.926-1.015 4.35z"></path></svg></a> <a aria-controls="gs_cit" aria-haspopup="true" class="gs_or_cit gs_nph" href="javascript:void(0)" role="button" title="Cite"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M1.5 3.5v5h2v.375L1.75 12.5h3L6.5 8.875V3.5zM9.5 3.5v5h2v.375L9.75 12.5h3L14.5 8.875V3.5z"></path></svg></a> <a href="/scholar?cites=13593770165181764102&amp;as_sdt=2005&amp;sciodt=0,5&amp;hl=en&amp;oe=ASCII">Cited by 1283</a> <a href="/scholar?q=related:BlL2PfHFprwJ:scholar.google.com/&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">Related articles</a> <a class="gs_nph" href="/scholar?cluster=13593770165181764102&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">All 18 versions</a> <a class="gs_or_mor gs_oph" href="javascript:void(0)" role="button" title="More"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M1.5 5.5l2-2L8 8l-4.5 4.5-2-2L4 8zM8.5 5.5l2-2L15 8l-4.5 4.5-2-2L11 8z"></path></svg></a> <a class="gs_or_nvi gs_or_mor" href="javascript:void(0)" role="button" title="Fewer"><svg class="gs_or_svg" viewbox="0 0 17 16"><path d="M8.5 5.5l-2-2L2 8l4.5 4.5 2-2L6 8zM15.5 5.5l-2-2L9 8l4.5 4.5 2-2L13 8z"></path></svg></a></div></div>,
#  <div class="gs_a">C De Rham, <a href="/citations?user=XuY4eFQAAAAJ&amp;hl=en&amp;oe=ASCII&amp;oi=sra">G Gabadadze</a>, AJ Tolley - Physical Review Letters, 2011 - APS</div>,
#  <div class="gs_rs">We construct four-dimensional covariant nonlinear theories of massive <b>gravity </b>which are <br/>ghost-free in the decoupling limit to all orders. These theories resum explicitly all the <br/>nonlinear terms of an effective field theory of massive <b>gravity</b>. We show that away from the …</div>,
#  <div class="gs_fl"><a class="gs_or_sav" href="javascript:void(0)" role="button" title="Save"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M8 11.57l3.824 2.308-1.015-4.35 3.379-2.926-4.45-.378L8 2.122 6.261 6.224l-4.449.378 3.379 2.926-1.015 4.35z"></path></svg></a> <a aria-controls="gs_cit" aria-haspopup="true" class="gs_or_cit gs_nph" href="javascript:void(0)" role="button" title="Cite"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M1.5 3.5v5h2v.375L1.75 12.5h3L6.5 8.875V3.5zM9.5 3.5v5h2v.375L9.75 12.5h3L14.5 8.875V3.5z"></path></svg></a> <a href="/scholar?cites=13593770165181764102&amp;as_sdt=2005&amp;sciodt=0,5&amp;hl=en&amp;oe=ASCII">Cited by 1283</a> <a href="/scholar?q=related:BlL2PfHFprwJ:scholar.google.com/&amp;scioq=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">Related articles</a> <a class="gs_nph" href="/scholar?cluster=13593770165181764102&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">All 18 versions</a> <a class="gs_or_mor gs_oph" href="javascript:void(0)" role="button" title="More"><svg class="gs_or_svg" viewbox="-1 0 17 16"><path d="M1.5 5.5l2-2L8 8l-4.5 4.5-2-2L4 8zM8.5 5.5l2-2L15 8l-4.5 4.5-2-2L11 8z"></path></svg></a> <a class="gs_or_nvi gs_or_mor" href="javascript:void(0)" role="button" title="Fewer"><svg class="gs_or_svg" viewbox="0 0 17 16"><path d="M8.5 5.5l-2-2L2 8l4.5 4.5 2-2L6 8zM15.5 5.5l-2-2L9 8l4.5 4.5 2-2L13 8z"></path></svg></a></div>,
#  <div id="gs_res_ccl_bot"><div class="gs_r gs_alrt_btm gs_oph gs_ota"><a class="gs_btnM gs_in_ib" href="/scholar_alerts?view_op=create_alert_options&amp;hl=en&amp;alert_query=intitle:gravity&amp;alert_params=%3Fhl%3Den%26as_sdt%3D0,5"><span class="gs_ico"></span><span class="gs_lbl">Create alert</span></a></div><div id="gs_n" role="navigation"><center><table cellpadding="0" width="1%"><tr align="center" valign="top"><td align="right" nowrap=""><span class="gs_ico gs_ico_nav_first"></span><b style="display:block;margin-right:35px;visibility:hidden">Previous</b></td><td><span class="gs_ico gs_ico_nav_current"></span><b>1</b></td><td><a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>2</a></td><td><a href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>3</a></td><td><a href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>4</a></td><td><a href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>5</a></td><td><a href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>6</a></td><td><a href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>7</a></td><td><a href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>8</a></td><td><a href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>9</a></td><td><a href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>10</a></td><td align="left" nowrap=""><a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_next"></span><b style="display:block;margin-left:53px">Next</b></a></td></tr></table></center></div><div id="gs_nm" role="navigation"><button aria-label="Previous" class="gs_btnPL gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" disabled="" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button><button aria-label="Next" class="gs_btnPR gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" onclick="window.location='/scholar?start\x3d10\x26q\x3dgravity\x26hl\x3den\x26oe\x3dASCII\x26as_sdt\x3d0,5'" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button><div id="gs_nml"><b class="gs_nma">1</b><a class="gs_nma" href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">2</a><a class="gs_nma" href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">3</a><a class="gs_nma" href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">4</a><a class="gs_nma" href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">5</a><a class="gs_nma" href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">6</a><a class="gs_nma" href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">7</a><a class="gs_nma" href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">8</a><a class="gs_nma" href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">9</a><a class="gs_nma" href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">10</a></div></div></div>,
#  <div class="gs_r gs_alrt_btm gs_oph gs_ota"><a class="gs_btnM gs_in_ib" href="/scholar_alerts?view_op=create_alert_options&amp;hl=en&amp;alert_query=intitle:gravity&amp;alert_params=%3Fhl%3Den%26as_sdt%3D0,5"><span class="gs_ico"></span><span class="gs_lbl">Create alert</span></a></div>,
#  <div id="gs_n" role="navigation"><center><table cellpadding="0" width="1%"><tr align="center" valign="top"><td align="right" nowrap=""><span class="gs_ico gs_ico_nav_first"></span><b style="display:block;margin-right:35px;visibility:hidden">Previous</b></td><td><span class="gs_ico gs_ico_nav_current"></span><b>1</b></td><td><a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>2</a></td><td><a href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>3</a></td><td><a href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>4</a></td><td><a href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>5</a></td><td><a href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>6</a></td><td><a href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>7</a></td><td><a href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>8</a></td><td><a href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>9</a></td><td><a href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_page"></span>10</a></td><td align="left" nowrap=""><a href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5"><span class="gs_ico gs_ico_nav_next"></span><b style="display:block;margin-left:53px">Next</b></a></td></tr></table></center></div>,
#  <div id="gs_nm" role="navigation"><button aria-label="Previous" class="gs_btnPL gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" disabled="" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button><button aria-label="Next" class="gs_btnPR gs_in_ib gs_btn_lrge gs_btn_half gs_btn_lsu" onclick="window.location='/scholar?start\x3d10\x26q\x3dgravity\x26hl\x3den\x26oe\x3dASCII\x26as_sdt\x3d0,5'" type="button"><span class="gs_wr"><span class="gs_ico"></span><span class="gs_lbl"></span></span></button><div id="gs_nml"><b class="gs_nma">1</b><a class="gs_nma" href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">2</a><a class="gs_nma" href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">3</a><a class="gs_nma" href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">4</a><a class="gs_nma" href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">5</a><a class="gs_nma" href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">6</a><a class="gs_nma" href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">7</a><a class="gs_nma" href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">8</a><a class="gs_nma" href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">9</a><a class="gs_nma" href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">10</a></div></div>,
#  <div id="gs_nml"><b class="gs_nma">1</b><a class="gs_nma" href="/scholar?start=10&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">2</a><a class="gs_nma" href="/scholar?start=20&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">3</a><a class="gs_nma" href="/scholar?start=30&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">4</a><a class="gs_nma" href="/scholar?start=40&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">5</a><a class="gs_nma" href="/scholar?start=50&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">6</a><a class="gs_nma" href="/scholar?start=60&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">7</a><a class="gs_nma" href="/scholar?start=70&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">8</a><a class="gs_nma" href="/scholar?start=80&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">9</a><a class="gs_nma" href="/scholar?start=90&amp;q=gravity&amp;hl=en&amp;oe=ASCII&amp;as_sdt=0,5">10</a></div>,
#  <div id="gs_ftr_sp" role="presentation"></div>,
#  <div id="gs_ftr" role="contentinfo"><div id="gs_ftr_rt"><a href="/intl/en/scholar/about.html">Help</a><a href="//www.google.se/intl/en/policies/privacy/">Privacy</a><a href="//www.google.se/intl/en/policies/terms/">Terms</a></div></div>,
#  <div id="gs_ftr_rt"><a href="/intl/en/scholar/about.html">Help</a><a href="//www.google.se/intl/en/policies/privacy/">Privacy</a><a href="//www.google.se/intl/en/policies/terms/">Terms</a></div>]
