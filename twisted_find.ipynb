# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from urllib.request import urlopen

# %%
arxiv_urls = ['https://arxiv.org/archive/cond-mat']

key_words_set1 = ["magic angle"]

def build_dataset(arxiv_urls):
    news_data = []
    for url in arxiv_urls:
        news_category = url.split('/')[-1]
        data = requests.get(url)
        soup = BeautifulSoup(data.content, 'html.parser')
        
        news_articles = [{'news_headline': headline.find('span', 
                                                         attrs={"itemprop": "headline"}).string,
                          'news_article': article.find('div', 
                                                       attrs={"itemprop": "articleBody"}).string,
                          'news_category': news_category}
                         
                            for headline, article in 
                             zip(soup.find_all('div', 
                                               class_=["news-card-title news-right-box"]),
                                 soup.find_all('div', 
                                               class_=["news-card-content news-right-box"]))
                        ]
        news_data.extend(news_articles)
        
    df =  pd.DataFrame(news_data)
    df = df[['news_headline', 'news_article', 'news_category']]
    return df

# %%
r = requests.get(google_scholar_url + query)

# %%
google_scholar_url = "http://scholar.google.se/scholar?hl=en&q="

# %%
print(google_scholar_url + query)
# Out:
# http://scholar.google.se/scholar?hl=en&q=gravity

# %%
arxiv_query = "http://export.arxiv.org/api/query?search_query=all:twisted+AND+all:graphene" #+all:bilayer

# %%
param_ = "&start=0&max_results=1000"

# %%
query = arxiv_query + param_

# %%
query_results = requests.get(query)

# %%
soup = BeautifulSoup(query_results.content,'html.parser')

# %%
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom">
# <link href="http://arxiv.org/api/query?search_query%3Dall%3Atwisted%20AND%20all%3Agraphene%26id_list%3D%26start%3D0%26max_results%3D1000" rel="self" type="application/atom+xml"/>
# <title type="html">ArXiv Query: search_query=all:twisted AND all:graphene&amp;id_list=&amp;start=0&amp;max_results=1000</title>
# <id>http://arxiv.org/api/Fbi5MkJkEuZjzMv4Ext33Y51lkM</id>
# <updated>2019-05-16T00:00:00-04:00</updated>
# <opensearch:totalresults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">400</opensearch:totalresults>
# <opensearch:startindex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startindex>
# <opensearch:itemsperpage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">1000</opensearch:itemsperpage>
# <entry>
# <id>http://arxiv.org/abs/1905.00622v1</id>
# <updated>2019-05-02T08:54:25Z</updated>
# <published>2019-05-02T08:54:25Z</published>
# ...

# %%
title = [{'title':i.get_text().replace('\n','').replace('$','')} for i in soup.find_all('title') ]

# %%
title
# Out:
# [{'title': 'ArXiv Query: search_query=all:twisted AND all:graphene&id_list=&start=0&max_results=1000'},
#  {'title': 'Topological flat bands in twisted trilayer graphene'},
#  {'title': 'An In-situ Annealing effect of Graphene-Graphene Interlayer Conduction'},
#  {'title': 'Phonons in Twisted Bilayer Graphene'},
#  {'title': 'Strong Electronic Correlation Originates from the Synergistic Effect of  Large Moiré Cell and Strong Interlayer Coupling in Twisted Graphene Bilayer'},
#  {'title': 'Observation of superconductivity with Tc onset at 12K in electrically  tunable twisted double bilayer graphene'},
#  {'title': 'Flatbands in twisted bi-bilayer graphene'},
#  {'title': 'Specific Heat of Twisted Bilayer Graphene'},
#  {'title': 'Theory for the electronic structure of incommensurate twisted bilayer  graphene'},
#  {'title': 'Topologically Protected Zero Modes in Twisted Bilayer Graphene'},
#  {'title': 'Interlayer Configurations in Twisted Bilayers of Folded Graphene'},
# ...

# %%
df = pd.DataFrame(title[1:])

# %%
df
# Out:
#                                                  title
# 0    Topological flat bands in twisted trilayer gra...
# 1    An In-situ Annealing effect of Graphene-Graphe...
# 2                  Phonons in Twisted Bilayer Graphene
# 3    Strong Electronic Correlation Originates from ...
# 4    Observation of superconductivity with Tc onset...
# 5             Flatbands in twisted bi-bilayer graphene
# 6            Specific Heat of Twisted Bilayer Graphene
# 7    Theory for the electronic structure of incomme...
# 8    Topologically Protected Zero Modes in Twisted ...
# 9    Interlayer Configurations in Twisted Bilayers ...
# 10   Minimum model for the electronic structure of ...
# 11   Band-unfolding approach to Moirè-induced band-...
# 12   Scanning tunneling microscopy and spectroscopy...
# 13   Single-electron gap in the spectrum of twisted...
# 14   Observation of Low Energy Raman Modes in Twist...
# 15   Spatially resolved electronic structure of twi...
# ...

# %%
df.iloc[296]['title']
# Out:
# 'The Axion Insulator as a Pump of Fragile Topology'

# %%
k = "abc\n abc\n"

# %%
k.replace(['a','b'],['e','f'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-4894fd81c9be> in <module>()
# ----> 1 k.replace(['a','b'],['e','f'])
#
# TypeError: replace() argument 1 must be str, not list

# %%
k
# Out:
# 'abc\n abc\n'
